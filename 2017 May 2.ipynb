# %% [markdown]
# ### MA755 Machine Learning - Chapter 10. Introduction to Artificial Neural Networks - 2 May 2017
#
# These notes are based on, and include images from, [_Hands-On Machine Learning with Scikit-Learn and TensorFlow_](http://shop.oreilly.com/product/0636920052289.do) by Aurélien Géron, published by O'Reilly Media, Inc., 2017

# %%
# !pip install tensorflow --quiet

# %%
import tensorflow as tf
import numpy      as np

# %% [markdown]
# The basic building block of a neural network is a _linear threshold unit_ (LTU.)

# %% [markdown]
# ###  Linear Threshold Unit (LTU)
#
# A _linear threshold unit_ is defined with:
#
# - _weights_: $\textbf{w}=w_1, w_2, ..., w_m$
# - _input_: $\textbf{x}=x_1, x_2, ..., x_m$ (a vector of independent variable values, for a row)
# - _output_: $\operatorname{step}({w}^{T}\cdot\textbf{x})=\operatorname{step}(w_1 x_1 + w_2 x_2, ..., w_n x_m)$
#
# where the most common step function is the heaviside function:
# \begin{align}
# \operatorname{heaviside}(z) = 0 & \text{ if } z < 0
# \\                          = 1 & \text{ if } z \ge 0
# \end{align}

# %% [markdown]
# In practice the step function is not the heaviside function, but it is included below to demonstrate the origins of the LTU.

# %% [markdown]
# ![alt](LTU.png)
# Source: Hands-On Machine Learning with Scikit-Learn and TensorFlow by Aurélien Géron

# %% [markdown]
# __Notice that the weights are associated with the edges (or arrows.)__

# %% [markdown]
# ### Perceptron
#
# > A Perceptron is simply composed of a single layer of LTUs, with each neuron connected to all the inputs.
#
# In addition, each neuron is connected to all of the outputs.
#
# The perceptron `fit` method:
# - input: a 2D numpy array of shape `(n_samples, n_features()`
# - input: a 1D numpy array of shape `(n_samples,)`
# - output: multiple binary values (multioutput)
#
# The following code is a mini-example of the `Perceptron` function.

# %%
from sklearn.datasets     import load_iris
from sklearn.linear_model import Perceptron

iris = load_iris()
X = iris.data[:, (2, 3)]  # petal length, petal width
y = (iris.target == 0).astype(np.int)  # Iris Setosa?

per_clf = Perceptron(random_state=42)
per_clf.fit(X, y)

y_pred = per_clf.predict([[2, 0.5]])
y_pred
# Out:
# array([1])

# %% [markdown]
# The perceptron model is graphically displayed below.

# %% [markdown]
# ![alt](perceptron.png)
# Source: Hands-On Machine Learning with Scikit-Learn and TensorFlow by Aurélien Géron

# %% [markdown]
# ### Perceptron learning rule (weight update)
#
# The network is a flow chart which takes input values to output values. The arrows and their weights determine the output(s) for each set of inputs.
#
# Below the weight $w_{i,j}$ is the arrow between the $i$-th input neuron and the $j$-th output neuron. This and other details are listed below.

# %% [markdown]
# ![alt](perceptronlearningrule.png)

# %% [markdown]
# Where:
# - $w_{i, j}$ is the connection weight between the $i$-th input neuron and the $j$-th output neuron
# - $x_i$ is the ith input value of the current training instance
# - $\hat{y}_j$ is the predicted output of the $j$-th output neuron for the current training instance
# - $y_j$ is the target output of the $j$-th output neuron for the current training instance
# - $\eta$ is the learning rate
#
# Assuming that the learning rate is positive (in the text it is set to `1`) I believe the expression $\hat{y}_j - y_j$ from the text (above) should be reversed.
#
# Exercise: Check this. See also [Perceptron at Wikipedia](https://en.wikipedia.org/wiki/Perceptron).

# %% [markdown]
# ### Replacing the step function
#
# The step function only returns two values (`0` and `1`), its derivative is zero everywhere and so the gradient is not useful.

# %% [markdown]
# For these reasons it is replaced with an __activation function__, such as one of the logistic/sigmoid, hyperbolic tangent or ReLU functions.
#
# Sigmoid function:
# $$\sigma(z) = \frac{1}{1 + e^{(-z)}}
# $$
#
# Hypbolic tangent function:
# $$\tanh(z) =  2\sigma(2z) – 1
# $$
#
# ReLU function:
# $$\operatorname{ReLU}(z) = \max(0,z)
# $$
#
# In practice the ReLU function is used most often.
#
# These three functions and their derivatives are displayed below.

# %% [markdown]
# ![alt](derivatives.png)

# %% [markdown]
# ### Softmax
#
# When a neural network is used for classification and the number of classes predicted is greater than two, then the softmax function can provide, for each instance, probabilities for each class that add to `1`.
#
# The softmax function has $K$ input values $z_j$ for $j=1, ..., K$ and $K$ output values
# $$
#     \sigma(z)_j = \frac{e^{z_j}}{\sum_{k=1}^K e^{z_k}}
# $$
# for $j=1, ..., K$ where $K$ is usually the number of classes of the target variable.
#
# These output values are interpreted as probabilities.
#
# See [Softmax at Wikipedia](https://en.wikipedia.org/wiki/Softmax_function).

# %% [markdown]
# ![alt](softmax.png)

# %% [markdown]
# ### Multi-Layer Perceptron (MLP)
#
# A MLP consists of multiple layers of LTUs. See graphic below.

# %% [markdown]
# ![alt](mlp.png)

# %% [markdown]
# > For each training instance,
# 1. the algorithm feeds it to the network and computes the output of every neuron in each consecutive layer (this is the forward pass, just like when making predictions).
# 1. Then it measures the network’s output error (i.e., the difference between the desired output and the actual output of the network), and it computes how much each neuron in the last hidden layer contributed to each output neuron’s error.
# 1. It then proceeds to measure how much of these error contributions came from each neuron in the previous hidden layer—and so on until the algorithm reaches the input layer. This reverse pass efficiently measures the error gradient across all the connection weights in the network by propagating the error gradient backward in the network (hence the name of the algorithm).

# %% [markdown]
# ### Training Model
#
# > For each training instance the _backpropagation algorithm_ first makes a prediction (forward pass), measures the error, then goes through each layer in reverse to measure the error contribution from each connection (reverse pass), and finally slightly tweaks the connection weights to reduce the error (Gradient Descent step).
#
# 1. For each instance, feed its input values into the network and successively calculate each layer. The last layer calculates the prediction
# 1. Measure the error at each layer (in reverse order of the previous step)
# 1. Modify the weights to decrease the error (gradient descent)

# %% [markdown]
# ### Training Model - Backpropogation
#
# For a nicely worked out example, code and visualizations see:
# - https://mattmazur.com/2015/03/17/a-step-by-step-backpropagation-example/

# %% [markdown]
# ### The `sklearn` implementation of MLP
#
# - http://scikit-learn.org/stable/modules/neural_networks_supervised.html

# %% [markdown]
# ### Training an MLP with TensorFlow’s High-Level API
#
# Use function `DNNClassifier` from the `tensorflow.contrib.learn` class.

# %%
import pickle
mnist = pickle.load(open( "mnist.p", "rb" ))

# %%
print("mnist.data.shape  ", mnist.data.shape)
print("mnist.target.shape", mnist.target.shape)
# Out:
# mnist.data.shape   (70000, 784)
# mnist.target.shape (70000,)

# %%
from sklearn.preprocessing   import StandardScaler
mnist_data_scaled = StandardScaler().fit_transform(mnist.data.astype(float))

# %%
from sklearn.model_selection import train_test_split

mnist_data_scaled = StandardScaler().fit_transform(mnist.data.astype(float))
mnist_target      = mnist.target.astype(int)

(train_data,        test_data, 
 train_target,      test_target, 
) = train_test_split(mnist_data_scaled,
                     mnist_target,
                     test_size=0.2, 
                     random_state=42)

(train_data.shape,        test_data.shape, 
 train_target.shape,      test_target.shape,
)
# Out:
# ((56000, 784), (14000, 784), (56000,), (14000,))

# %%
import tensorflow as tf

feature_columns = tf.contrib.learn.infer_real_valued_columns_from_input(train_data)
dnn_clf = tf.contrib.learn.DNNClassifier(hidden_units=[300, 100], n_classes=10,
                                         feature_columns=feature_columns)
dnn_clf.fit(x=train_data, y=train_target, batch_size=50, steps=40000)
# Out:
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_num_ps_replicas': 0, '_keep_checkpoint_max': 5, '_environment': 'local', '_model_dir': None, '_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_keep_checkpoint_every_n_hours': 10000, '_save_checkpoints_steps': None, '_save_summary_steps': 100, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f48c0dfa828>, '_task_id': 0, '_is_chief': True, '_evaluation_master': '', '_save_checkpoints_secs': 600, '_master': '', '_task_type': None, '_num_worker_replicas': 0, '_tf_random_seed': None}
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmp9jmnril0
# WARNING:tensorflow:From <ipython-input-8-327b84f10bbf>:6: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-8-327b84f10bbf>:6: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-8-327b84f10bbf>:6: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with batch_size is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# WARNING:tensorflow:From /opt/conda/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Create CheckpointSaverHook.
# /opt/conda/lib/python3.5/site-packages/tensorflow/python/util/deprecation.py:248: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   equality = a == b
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmp9jmnril0/model.ckpt.
# INFO:tensorflow:step = 1, loss = 3.10086
# INFO:tensorflow:global_step/sec: 162.682
# INFO:tensorflow:step = 101, loss = 0.20997 (0.616 sec)
# INFO:tensorflow:global_step/sec: 178.593
# INFO:tensorflow:step = 201, loss = 0.207866 (0.560 sec)
# INFO:tensorflow:global_step/sec: 163.248
# INFO:tensorflow:step = 301, loss = 0.312136 (0.613 sec)
# INFO:tensorflow:global_step/sec: 160.628
# INFO:tensorflow:step = 401, loss = 0.247611 (0.622 sec)
# INFO:tensorflow:global_step/sec: 147.667
# INFO:tensorflow:step = 501, loss = 0.218117 (0.679 sec)
# INFO:tensorflow:global_step/sec: 199.727
# INFO:tensorflow:step = 601, loss = 0.179193 (0.499 sec)
# INFO:tensorflow:global_step/sec: 193.49
# INFO:tensorflow:step = 701, loss = 0.0936187 (0.517 sec)
# INFO:tensorflow:global_step/sec: 205.64
# INFO:tensorflow:step = 801, loss = 0.315023 (0.486 sec)
# INFO:tensorflow:global_step/sec: 201.876
# INFO:tensorflow:step = 901, loss = 0.062643 (0.495 sec)
# INFO:tensorflow:global_step/sec: 203.635
# INFO:tensorflow:step = 1001, loss = 0.2173 (0.491 sec)
# INFO:tensorflow:global_step/sec: 202.102
# INFO:tensorflow:step = 1101, loss = 0.0429376 (0.495 sec)
# INFO:tensorflow:global_step/sec: 187.701
# INFO:tensorflow:step = 1201, loss = 0.135978 (0.533 sec)
# INFO:tensorflow:global_step/sec: 199.918
# INFO:tensorflow:step = 1301, loss = 0.0699442 (0.500 sec)
# INFO:tensorflow:global_step/sec: 209.084
# INFO:tensorflow:step = 1401, loss = 0.0175749 (0.478 sec)
# INFO:tensorflow:global_step/sec: 220.307
# INFO:tensorflow:step = 1501, loss = 0.0135064 (0.454 sec)
# INFO:tensorflow:global_step/sec: 219.827
# INFO:tensorflow:step = 1601, loss = 0.0389029 (0.455 sec)
# INFO:tensorflow:global_step/sec: 225.562
# INFO:tensorflow:step = 1701, loss = 0.183573 (0.444 sec)
# INFO:tensorflow:global_step/sec: 204.09
# INFO:tensorflow:step = 1801, loss = 0.0758783 (0.491 sec)
# INFO:tensorflow:global_step/sec: 207.656
# INFO:tensorflow:step = 1901, loss = 0.0728248 (0.480 sec)
# INFO:tensorflow:global_step/sec: 211.547
# INFO:tensorflow:step = 2001, loss = 0.0145521 (0.473 sec)
# INFO:tensorflow:global_step/sec: 203.461
# INFO:tensorflow:step = 2101, loss = 0.12559 (0.491 sec)
# INFO:tensorflow:global_step/sec: 214.192
# INFO:tensorflow:step = 2201, loss = 0.0787043 (0.468 sec)
# INFO:tensorflow:global_step/sec: 217.932
# INFO:tensorflow:step = 2301, loss = 0.0408499 (0.459 sec)
# INFO:tensorflow:global_step/sec: 226.82
# INFO:tensorflow:step = 2401, loss = 0.0314288 (0.440 sec)
# INFO:tensorflow:global_step/sec: 218.275
# INFO:tensorflow:step = 2501, loss = 0.00504538 (0.459 sec)
# INFO:tensorflow:global_step/sec: 211.413
# INFO:tensorflow:step = 2601, loss = 0.0679863 (0.472 sec)
# INFO:tensorflow:global_step/sec: 211.179
# INFO:tensorflow:step = 2701, loss = 0.062955 (0.474 sec)
# INFO:tensorflow:global_step/sec: 225.574
# INFO:tensorflow:step = 2801, loss = 0.0205925 (0.444 sec)
# INFO:tensorflow:global_step/sec: 212.052
# INFO:tensorflow:step = 2901, loss = 0.0863596 (0.472 sec)
# INFO:tensorflow:global_step/sec: 199.57
# INFO:tensorflow:step = 3001, loss = 0.0693672 (0.501 sec)
# INFO:tensorflow:global_step/sec: 187.119
# INFO:tensorflow:step = 3101, loss = 0.0323411 (0.534 sec)
# INFO:tensorflow:global_step/sec: 175.738
# INFO:tensorflow:step = 3201, loss = 0.0243447 (0.570 sec)
# INFO:tensorflow:global_step/sec: 203.886
# INFO:tensorflow:step = 3301, loss = 0.0205878 (0.490 sec)
# INFO:tensorflow:global_step/sec: 211.341
# INFO:tensorflow:step = 3401, loss = 0.0566107 (0.473 sec)
# INFO:tensorflow:global_step/sec: 202.601
# INFO:tensorflow:step = 3501, loss = 0.0148043 (0.494 sec)
# INFO:tensorflow:global_step/sec: 198.764
# INFO:tensorflow:step = 3601, loss = 0.00778894 (0.503 sec)
# INFO:tensorflow:global_step/sec: 222.258
# INFO:tensorflow:step = 3701, loss = 0.0112934 (0.450 sec)
# INFO:tensorflow:global_step/sec: 216.813
# INFO:tensorflow:step = 3801, loss = 0.0164802 (0.461 sec)
# INFO:tensorflow:global_step/sec: 216.077
# INFO:tensorflow:step = 3901, loss = 0.108276 (0.463 sec)
# INFO:tensorflow:global_step/sec: 217.665
# INFO:tensorflow:step = 4001, loss = 0.0207789 (0.461 sec)
# INFO:tensorflow:global_step/sec: 216.776
# INFO:tensorflow:step = 4101, loss = 0.0551521 (0.461 sec)
# INFO:tensorflow:global_step/sec: 219.782
# INFO:tensorflow:step = 4201, loss = 0.0331167 (0.455 sec)
# INFO:tensorflow:global_step/sec: 212.37
# INFO:tensorflow:step = 4301, loss = 0.0199606 (0.471 sec)
# INFO:tensorflow:global_step/sec: 204.332
# INFO:tensorflow:step = 4401, loss = 0.0773104 (0.490 sec)
# INFO:tensorflow:global_step/sec: 203.92
# INFO:tensorflow:step = 4501, loss = 0.0662467 (0.489 sec)
# INFO:tensorflow:global_step/sec: 205.065
# INFO:tensorflow:step = 4601, loss = 0.00246281 (0.488 sec)
# INFO:tensorflow:global_step/sec: 213.619
# INFO:tensorflow:step = 4701, loss = 0.0202787 (0.469 sec)
# INFO:tensorflow:global_step/sec: 206.492
# INFO:tensorflow:step = 4801, loss = 0.00930328 (0.484 sec)
# INFO:tensorflow:global_step/sec: 207.431
# INFO:tensorflow:step = 4901, loss = 0.0274798 (0.482 sec)
# INFO:tensorflow:global_step/sec: 209.678
# INFO:tensorflow:step = 5001, loss = 0.00579901 (0.477 sec)
# INFO:tensorflow:global_step/sec: 213.512
# INFO:tensorflow:step = 5101, loss = 0.213267 (0.467 sec)
# INFO:tensorflow:global_step/sec: 214.893
# INFO:tensorflow:step = 5201, loss = 0.0144558 (0.465 sec)
# INFO:tensorflow:global_step/sec: 207.749
# INFO:tensorflow:step = 5301, loss = 0.00942309 (0.481 sec)
# INFO:tensorflow:global_step/sec: 201.312
# INFO:tensorflow:step = 5401, loss = 0.00178903 (0.497 sec)
# INFO:tensorflow:global_step/sec: 186.892
# INFO:tensorflow:step = 5501, loss = 0.00464572 (0.535 sec)
# INFO:tensorflow:global_step/sec: 194.018
# INFO:tensorflow:step = 5601, loss = 0.0039855 (0.515 sec)
# INFO:tensorflow:global_step/sec: 189.775
# INFO:tensorflow:step = 5701, loss = 0.0130955 (0.527 sec)
# INFO:tensorflow:global_step/sec: 191.211
# INFO:tensorflow:step = 5801, loss = 0.00576111 (0.523 sec)
# INFO:tensorflow:global_step/sec: 186.939
# INFO:tensorflow:step = 5901, loss = 0.00213864 (0.535 sec)
# INFO:tensorflow:global_step/sec: 161.092
# INFO:tensorflow:step = 6001, loss = 0.00649236 (0.622 sec)
# INFO:tensorflow:global_step/sec: 169.573
# INFO:tensorflow:step = 6101, loss = 0.00758054 (0.589 sec)
# INFO:tensorflow:global_step/sec: 153.556
# INFO:tensorflow:step = 6201, loss = 0.000778664 (0.652 sec)
# INFO:tensorflow:global_step/sec: 148.109
# INFO:tensorflow:step = 6301, loss = 0.0045737 (0.675 sec)
# INFO:tensorflow:global_step/sec: 189.239
# INFO:tensorflow:step = 6401, loss = 0.00234818 (0.528 sec)
# INFO:tensorflow:global_step/sec: 211.096
# INFO:tensorflow:step = 6501, loss = 0.00201834 (0.474 sec)
# INFO:tensorflow:global_step/sec: 213.679
# INFO:tensorflow:step = 6601, loss = 0.00528455 (0.468 sec)
# INFO:tensorflow:global_step/sec: 209.149
# INFO:tensorflow:step = 6701, loss = 0.00371126 (0.479 sec)
# INFO:tensorflow:global_step/sec: 213.697
# INFO:tensorflow:step = 6801, loss = 0.00608716 (0.467 sec)
# INFO:tensorflow:global_step/sec: 211.687
# INFO:tensorflow:step = 6901, loss = 0.0162735 (0.474 sec)
# INFO:tensorflow:global_step/sec: 198.226
# INFO:tensorflow:step = 7001, loss = 0.00211198 (0.504 sec)
# INFO:tensorflow:global_step/sec: 218.379
# INFO:tensorflow:step = 7101, loss = 0.000513772 (0.457 sec)
# INFO:tensorflow:global_step/sec: 215.17
# INFO:tensorflow:step = 7201, loss = 0.00438844 (0.465 sec)
# INFO:tensorflow:global_step/sec: 188.881
# INFO:tensorflow:step = 7301, loss = 0.00656244 (0.530 sec)
# INFO:tensorflow:global_step/sec: 224.499
# INFO:tensorflow:step = 7401, loss = 0.00137019 (0.446 sec)
# INFO:tensorflow:global_step/sec: 217.045
# INFO:tensorflow:step = 7501, loss = 0.00151487 (0.461 sec)
# INFO:tensorflow:global_step/sec: 215.351
# INFO:tensorflow:step = 7601, loss = 0.00628201 (0.464 sec)
# INFO:tensorflow:global_step/sec: 214.701
# INFO:tensorflow:step = 7701, loss = 0.0015466 (0.465 sec)
# INFO:tensorflow:global_step/sec: 223.214
# INFO:tensorflow:step = 7801, loss = 0.00397462 (0.449 sec)
# INFO:tensorflow:global_step/sec: 212.056
# INFO:tensorflow:step = 7901, loss = 0.000756174 (0.471 sec)
# INFO:tensorflow:global_step/sec: 212.985
# INFO:tensorflow:step = 8001, loss = 0.0113182 (0.470 sec)
# INFO:tensorflow:global_step/sec: 218.498
# INFO:tensorflow:step = 8101, loss = 0.00057136 (0.458 sec)
# INFO:tensorflow:global_step/sec: 222.653
# INFO:tensorflow:step = 8201, loss = 0.00416775 (0.449 sec)
# INFO:tensorflow:global_step/sec: 196.814
# INFO:tensorflow:step = 8301, loss = 0.00244798 (0.507 sec)
# INFO:tensorflow:global_step/sec: 213.449
# INFO:tensorflow:step = 8401, loss = 0.000657404 (0.468 sec)
# INFO:tensorflow:global_step/sec: 220.615
# INFO:tensorflow:step = 8501, loss = 0.000135048 (0.453 sec)
# INFO:tensorflow:global_step/sec: 212.72
# INFO:tensorflow:step = 8601, loss = 0.00132962 (0.470 sec)
# INFO:tensorflow:global_step/sec: 203.871
# INFO:tensorflow:step = 8701, loss = 0.00252157 (0.491 sec)
# INFO:tensorflow:global_step/sec: 208.04
# INFO:tensorflow:step = 8801, loss = 0.0076482 (0.481 sec)
# INFO:tensorflow:global_step/sec: 211.733
# INFO:tensorflow:step = 8901, loss = 0.00976924 (0.474 sec)
# INFO:tensorflow:global_step/sec: 218.102
# INFO:tensorflow:step = 9001, loss = 0.00302115 (0.458 sec)
# INFO:tensorflow:global_step/sec: 220.012
# INFO:tensorflow:step = 9101, loss = 0.00249461 (0.455 sec)
# INFO:tensorflow:global_step/sec: 211.598
# INFO:tensorflow:step = 9201, loss = 0.00145177 (0.471 sec)
# INFO:tensorflow:global_step/sec: 217.089
# INFO:tensorflow:step = 9301, loss = 0.000354025 (0.461 sec)
# INFO:tensorflow:global_step/sec: 220.231
# INFO:tensorflow:step = 9401, loss = 0.00304666 (0.454 sec)
# INFO:tensorflow:global_step/sec: 206.766
# INFO:tensorflow:step = 9501, loss = 0.00573913 (0.484 sec)
# INFO:tensorflow:global_step/sec: 214.464
# INFO:tensorflow:step = 9601, loss = 0.00316805 (0.466 sec)
# INFO:tensorflow:global_step/sec: 213.821
# INFO:tensorflow:step = 9701, loss = 0.000449843 (0.468 sec)
# INFO:tensorflow:global_step/sec: 213.128
# INFO:tensorflow:step = 9801, loss = 0.0022891 (0.469 sec)
# INFO:tensorflow:global_step/sec: 211.515
# INFO:tensorflow:step = 9901, loss = 0.00836585 (0.473 sec)
# INFO:tensorflow:global_step/sec: 219.416
# INFO:tensorflow:step = 10001, loss = 0.00396965 (0.456 sec)
# INFO:tensorflow:global_step/sec: 213.987
# INFO:tensorflow:step = 10101, loss = 0.00410386 (0.468 sec)
# INFO:tensorflow:global_step/sec: 212.713
# INFO:tensorflow:step = 10201, loss = 0.000452309 (0.470 sec)
# INFO:tensorflow:global_step/sec: 216.256
# INFO:tensorflow:step = 10301, loss = 0.00189546 (0.462 sec)
# INFO:tensorflow:global_step/sec: 213.672
# INFO:tensorflow:step = 10401, loss = 0.00178649 (0.468 sec)
# INFO:tensorflow:global_step/sec: 214.128
# INFO:tensorflow:step = 10501, loss = 0.000430263 (0.466 sec)
# INFO:tensorflow:global_step/sec: 206.404
# INFO:tensorflow:step = 10601, loss = 0.00104782 (0.484 sec)
# INFO:tensorflow:global_step/sec: 210.356
# INFO:tensorflow:step = 10701, loss = 0.00175033 (0.475 sec)
# INFO:tensorflow:global_step/sec: 217.543
# INFO:tensorflow:step = 10801, loss = 0.00155029 (0.460 sec)
# INFO:tensorflow:global_step/sec: 205.371
# INFO:tensorflow:step = 10901, loss = 0.00150045 (0.488 sec)
# INFO:tensorflow:global_step/sec: 215.786
# INFO:tensorflow:step = 11001, loss = 0.00108059 (0.462 sec)
# INFO:tensorflow:global_step/sec: 211.412
# INFO:tensorflow:step = 11101, loss = 0.000603814 (0.473 sec)
# INFO:tensorflow:global_step/sec: 203.088
# INFO:tensorflow:step = 11201, loss = 0.000558453 (0.492 sec)
# INFO:tensorflow:global_step/sec: 219.769
# INFO:tensorflow:step = 11301, loss = 0.00416548 (0.455 sec)
# INFO:tensorflow:global_step/sec: 208.614
# INFO:tensorflow:step = 11401, loss = 0.00168321 (0.479 sec)
# INFO:tensorflow:global_step/sec: 211.937
# INFO:tensorflow:step = 11501, loss = 0.00109167 (0.473 sec)
# INFO:tensorflow:global_step/sec: 216.948
# INFO:tensorflow:step = 11601, loss = 0.00104656 (0.461 sec)
# INFO:tensorflow:global_step/sec: 221.188
# INFO:tensorflow:step = 11701, loss = 0.00145862 (0.452 sec)
# INFO:tensorflow:global_step/sec: 209.855
# INFO:tensorflow:step = 11801, loss = 0.000892299 (0.477 sec)
# INFO:tensorflow:global_step/sec: 208.238
# INFO:tensorflow:step = 11901, loss = 0.00177731 (0.479 sec)
# INFO:tensorflow:global_step/sec: 201.27
# INFO:tensorflow:step = 12001, loss = 0.00346168 (0.497 sec)
# INFO:tensorflow:global_step/sec: 195.255
# INFO:tensorflow:step = 12101, loss = 0.00376847 (0.511 sec)
# INFO:tensorflow:global_step/sec: 206.366
# INFO:tensorflow:step = 12201, loss = 0.000267788 (0.485 sec)
# INFO:tensorflow:global_step/sec: 193.647
# INFO:tensorflow:step = 12301, loss = 0.000708879 (0.516 sec)
# INFO:tensorflow:global_step/sec: 198.79
# INFO:tensorflow:step = 12401, loss = 0.00032281 (0.503 sec)
# INFO:tensorflow:global_step/sec: 224.687
# INFO:tensorflow:step = 12501, loss = 0.000854318 (0.445 sec)
# INFO:tensorflow:global_step/sec: 210.447
# INFO:tensorflow:step = 12601, loss = 0.00236026 (0.475 sec)
# INFO:tensorflow:global_step/sec: 205.53
# INFO:tensorflow:step = 12701, loss = 0.00115909 (0.487 sec)
# INFO:tensorflow:global_step/sec: 209.507
# INFO:tensorflow:step = 12801, loss = 0.00110836 (0.477 sec)
# INFO:tensorflow:global_step/sec: 214.812
# INFO:tensorflow:step = 12901, loss = 0.00185456 (0.466 sec)
# INFO:tensorflow:global_step/sec: 217.286
# INFO:tensorflow:step = 13001, loss = 0.000136143 (0.460 sec)
# INFO:tensorflow:global_step/sec: 216.461
# INFO:tensorflow:step = 13101, loss = 0.000197228 (0.462 sec)
# INFO:tensorflow:global_step/sec: 209.004
# INFO:tensorflow:step = 13201, loss = 0.000778582 (0.479 sec)
# INFO:tensorflow:global_step/sec: 220.284
# INFO:tensorflow:step = 13301, loss = 0.000673782 (0.454 sec)
# INFO:tensorflow:global_step/sec: 225.143
# INFO:tensorflow:step = 13401, loss = 0.000253284 (0.444 sec)
# INFO:tensorflow:global_step/sec: 219.952
# INFO:tensorflow:step = 13501, loss = 0.000523954 (0.455 sec)
# INFO:tensorflow:global_step/sec: 209.516
# INFO:tensorflow:step = 13601, loss = 0.000179241 (0.478 sec)
# INFO:tensorflow:global_step/sec: 201.593
# INFO:tensorflow:step = 13701, loss = 0.00157141 (0.495 sec)
# INFO:tensorflow:global_step/sec: 213.687
# INFO:tensorflow:step = 13801, loss = 0.000227462 (0.468 sec)
# INFO:tensorflow:global_step/sec: 216.172
# INFO:tensorflow:step = 13901, loss = 0.000946539 (0.463 sec)
# INFO:tensorflow:global_step/sec: 220.054
# INFO:tensorflow:step = 14001, loss = 0.00128697 (0.454 sec)
# INFO:tensorflow:global_step/sec: 220.507
# INFO:tensorflow:step = 14101, loss = 0.00121298 (0.454 sec)
# INFO:tensorflow:global_step/sec: 218.948
# INFO:tensorflow:step = 14201, loss = 0.000436941 (0.457 sec)
# INFO:tensorflow:global_step/sec: 217.586
# INFO:tensorflow:step = 14301, loss = 0.000696308 (0.460 sec)
# INFO:tensorflow:global_step/sec: 216.097
# INFO:tensorflow:step = 14401, loss = 0.000286452 (0.463 sec)
# INFO:tensorflow:global_step/sec: 219.873
# INFO:tensorflow:step = 14501, loss = 0.000907722 (0.455 sec)
# INFO:tensorflow:global_step/sec: 219.261
# INFO:tensorflow:step = 14601, loss = 0.00132132 (0.456 sec)
# INFO:tensorflow:global_step/sec: 213.176
# INFO:tensorflow:step = 14701, loss = 0.00138579 (0.469 sec)
# INFO:tensorflow:global_step/sec: 198.865
# INFO:tensorflow:step = 14801, loss = 0.00153326 (0.503 sec)
# INFO:tensorflow:global_step/sec: 213.812
# INFO:tensorflow:step = 14901, loss = 0.000496211 (0.468 sec)
# INFO:tensorflow:global_step/sec: 198.94
# INFO:tensorflow:step = 15001, loss = 0.000696392 (0.503 sec)
# INFO:tensorflow:global_step/sec: 216.013
# INFO:tensorflow:step = 15101, loss = 0.00253923 (0.463 sec)
# INFO:tensorflow:global_step/sec: 212.02
# INFO:tensorflow:step = 15201, loss = 0.00211352 (0.473 sec)
# INFO:tensorflow:global_step/sec: 213.809
# INFO:tensorflow:step = 15301, loss = 0.000918905 (0.467 sec)
# INFO:tensorflow:global_step/sec: 210.846
# INFO:tensorflow:step = 15401, loss = 0.00126066 (0.474 sec)
# INFO:tensorflow:global_step/sec: 209.151
# INFO:tensorflow:step = 15501, loss = 0.00374178 (0.478 sec)
# INFO:tensorflow:global_step/sec: 217.761
# INFO:tensorflow:step = 15601, loss = 0.000759766 (0.459 sec)
# INFO:tensorflow:global_step/sec: 224.588
# INFO:tensorflow:step = 15701, loss = 0.00181022 (0.445 sec)
# INFO:tensorflow:global_step/sec: 216.043
# INFO:tensorflow:step = 15801, loss = 0.0016625 (0.463 sec)
# INFO:tensorflow:global_step/sec: 215.963
# INFO:tensorflow:step = 15901, loss = 0.000359248 (0.463 sec)
# INFO:tensorflow:global_step/sec: 214.19
# INFO:tensorflow:step = 16001, loss = 0.000358949 (0.467 sec)
# INFO:tensorflow:global_step/sec: 220.633
# INFO:tensorflow:step = 16101, loss = 0.0010605 (0.455 sec)
# INFO:tensorflow:global_step/sec: 214.947
# INFO:tensorflow:step = 16201, loss = 0.00117867 (0.464 sec)
# INFO:tensorflow:global_step/sec: 201.769
# INFO:tensorflow:step = 16301, loss = 0.000578199 (0.496 sec)
# INFO:tensorflow:global_step/sec: 220.48
# INFO:tensorflow:step = 16401, loss = 0.000277496 (0.453 sec)
# INFO:tensorflow:global_step/sec: 212.169
# INFO:tensorflow:step = 16501, loss = 0.00146454 (0.471 sec)
# INFO:tensorflow:global_step/sec: 218.129
# INFO:tensorflow:step = 16601, loss = 0.000361091 (0.459 sec)
# INFO:tensorflow:global_step/sec: 217.853
# INFO:tensorflow:step = 16701, loss = 0.000447328 (0.459 sec)
# INFO:tensorflow:global_step/sec: 217.751
# INFO:tensorflow:step = 16801, loss = 0.000491238 (0.459 sec)
# INFO:tensorflow:global_step/sec: 214.225
# INFO:tensorflow:step = 16901, loss = 0.000446719 (0.466 sec)
# INFO:tensorflow:global_step/sec: 219.668
# INFO:tensorflow:step = 17001, loss = 0.00138621 (0.456 sec)
# INFO:tensorflow:global_step/sec: 218.505
# INFO:tensorflow:step = 17101, loss = 0.000596387 (0.457 sec)
# INFO:tensorflow:global_step/sec: 218.792
# INFO:tensorflow:step = 17201, loss = 0.00258515 (0.458 sec)
# INFO:tensorflow:global_step/sec: 214.401
# INFO:tensorflow:step = 17301, loss = 0.00110401 (0.467 sec)
# INFO:tensorflow:global_step/sec: 221.101
# INFO:tensorflow:step = 17401, loss = 4.60988e-05 (0.451 sec)
# INFO:tensorflow:global_step/sec: 214.137
# INFO:tensorflow:step = 17501, loss = 0.00137797 (0.467 sec)
# INFO:tensorflow:global_step/sec: 208.122
# INFO:tensorflow:step = 17601, loss = 0.000322188 (0.481 sec)
# INFO:tensorflow:global_step/sec: 207.353
# INFO:tensorflow:step = 17701, loss = 0.000407089 (0.483 sec)
# INFO:tensorflow:global_step/sec: 207.764
# INFO:tensorflow:step = 17801, loss = 0.000729179 (0.481 sec)
# INFO:tensorflow:global_step/sec: 204.469
# INFO:tensorflow:step = 17901, loss = 0.000452934 (0.489 sec)
# INFO:tensorflow:global_step/sec: 217.382
# INFO:tensorflow:step = 18001, loss = 0.000468566 (0.460 sec)
# INFO:tensorflow:global_step/sec: 214.658
# INFO:tensorflow:step = 18101, loss = 0.000466762 (0.465 sec)
# INFO:tensorflow:global_step/sec: 214.427
# INFO:tensorflow:step = 18201, loss = 0.000509667 (0.466 sec)
# INFO:tensorflow:global_step/sec: 218.169
# INFO:tensorflow:step = 18301, loss = 0.00023604 (0.458 sec)
# INFO:tensorflow:global_step/sec: 218.277
# INFO:tensorflow:step = 18401, loss = 0.000367648 (0.459 sec)
# INFO:tensorflow:global_step/sec: 213.833
# INFO:tensorflow:step = 18501, loss = 0.000127546 (0.467 sec)
# INFO:tensorflow:global_step/sec: 214.862
# INFO:tensorflow:step = 18601, loss = 0.000515567 (0.466 sec)
# INFO:tensorflow:global_step/sec: 213.556
# INFO:tensorflow:step = 18701, loss = 0.000579031 (0.467 sec)
# INFO:tensorflow:global_step/sec: 214.802
# INFO:tensorflow:step = 18801, loss = 0.000314799 (0.467 sec)
# INFO:tensorflow:global_step/sec: 210.778
# INFO:tensorflow:step = 18901, loss = 0.000193933 (0.474 sec)
# INFO:tensorflow:global_step/sec: 202.739
# INFO:tensorflow:step = 19001, loss = 0.00058193 (0.493 sec)
# INFO:tensorflow:global_step/sec: 216.916
# INFO:tensorflow:step = 19101, loss = 0.000342563 (0.460 sec)
# INFO:tensorflow:global_step/sec: 220.186
# INFO:tensorflow:step = 19201, loss = 0.000671534 (0.454 sec)
# INFO:tensorflow:global_step/sec: 215.639
# INFO:tensorflow:step = 19301, loss = 0.00107443 (0.464 sec)
# INFO:tensorflow:global_step/sec: 218.023
# INFO:tensorflow:step = 19401, loss = 0.000861464 (0.459 sec)
# INFO:tensorflow:global_step/sec: 207.565
# INFO:tensorflow:step = 19501, loss = 8.96116e-05 (0.482 sec)
# INFO:tensorflow:global_step/sec: 215.735
# INFO:tensorflow:step = 19601, loss = 0.000492046 (0.464 sec)
# INFO:tensorflow:global_step/sec: 218.239
# INFO:tensorflow:step = 19701, loss = 0.000169809 (0.458 sec)
# INFO:tensorflow:global_step/sec: 209.49
# INFO:tensorflow:step = 19801, loss = 0.000882321 (0.477 sec)
# INFO:tensorflow:global_step/sec: 215.613
# INFO:tensorflow:step = 19901, loss = 0.000164011 (0.465 sec)
# INFO:tensorflow:global_step/sec: 221.555
# INFO:tensorflow:step = 20001, loss = 0.000503466 (0.451 sec)
# INFO:tensorflow:global_step/sec: 183.171
# INFO:tensorflow:step = 20101, loss = 0.000263287 (0.545 sec)
# INFO:tensorflow:global_step/sec: 216.685
# INFO:tensorflow:step = 20201, loss = 0.000296727 (0.461 sec)
# INFO:tensorflow:global_step/sec: 212.633
# INFO:tensorflow:step = 20301, loss = 0.000432015 (0.470 sec)
# INFO:tensorflow:global_step/sec: 205.708
# INFO:tensorflow:step = 20401, loss = 0.000149044 (0.487 sec)
# INFO:tensorflow:global_step/sec: 211.865
# INFO:tensorflow:step = 20501, loss = 0.000506335 (0.471 sec)
# INFO:tensorflow:global_step/sec: 218.092
# INFO:tensorflow:step = 20601, loss = 0.000180144 (0.459 sec)
# INFO:tensorflow:global_step/sec: 206.852
# INFO:tensorflow:step = 20701, loss = 0.00070986 (0.482 sec)
# INFO:tensorflow:global_step/sec: 222.444
# INFO:tensorflow:step = 20801, loss = 0.00394369 (0.451 sec)
# INFO:tensorflow:global_step/sec: 212.711
# INFO:tensorflow:step = 20901, loss = 0.000816666 (0.470 sec)
# INFO:tensorflow:global_step/sec: 212.657
# INFO:tensorflow:step = 21001, loss = 5.3443e-05 (0.469 sec)
# INFO:tensorflow:global_step/sec: 213.501
# INFO:tensorflow:step = 21101, loss = 0.0013923 (0.468 sec)
# INFO:tensorflow:global_step/sec: 208.497
# INFO:tensorflow:step = 21201, loss = 0.000617989 (0.480 sec)
# INFO:tensorflow:global_step/sec: 206.907
# INFO:tensorflow:step = 21301, loss = 0.000826545 (0.483 sec)
# INFO:tensorflow:global_step/sec: 214.349
# INFO:tensorflow:step = 21401, loss = 0.000573717 (0.467 sec)
# INFO:tensorflow:global_step/sec: 207.179
# INFO:tensorflow:step = 21501, loss = 0.000621394 (0.483 sec)
# INFO:tensorflow:global_step/sec: 212.85
# INFO:tensorflow:step = 21601, loss = 0.000665825 (0.470 sec)
# INFO:tensorflow:global_step/sec: 191.383
# INFO:tensorflow:step = 21701, loss = 0.000104602 (0.522 sec)
# INFO:tensorflow:global_step/sec: 215.12
# INFO:tensorflow:step = 21801, loss = 0.00147076 (0.465 sec)
# INFO:tensorflow:global_step/sec: 223.255
# INFO:tensorflow:step = 21901, loss = 0.000408689 (0.448 sec)
# INFO:tensorflow:global_step/sec: 207.645
# INFO:tensorflow:step = 22001, loss = 5.86566e-05 (0.482 sec)
# INFO:tensorflow:global_step/sec: 213.44
# INFO:tensorflow:step = 22101, loss = 0.00245037 (0.468 sec)
# INFO:tensorflow:global_step/sec: 218.635
# INFO:tensorflow:step = 22201, loss = 0.000293155 (0.458 sec)
# INFO:tensorflow:global_step/sec: 219.776
# INFO:tensorflow:step = 22301, loss = 0.000154375 (0.455 sec)
# INFO:tensorflow:global_step/sec: 200.057
# INFO:tensorflow:step = 22401, loss = 6.79538e-05 (0.500 sec)
# INFO:tensorflow:global_step/sec: 212.191
# INFO:tensorflow:step = 22501, loss = 0.000269737 (0.471 sec)
# INFO:tensorflow:global_step/sec: 218.221
# INFO:tensorflow:step = 22601, loss = 0.000244804 (0.458 sec)
# INFO:tensorflow:global_step/sec: 212.989
# INFO:tensorflow:step = 22701, loss = 9.49279e-05 (0.470 sec)
# INFO:tensorflow:global_step/sec: 225.001
# INFO:tensorflow:step = 22801, loss = 0.000269807 (0.444 sec)
# INFO:tensorflow:global_step/sec: 195.408
# INFO:tensorflow:step = 22901, loss = 0.000519345 (0.512 sec)
# INFO:tensorflow:global_step/sec: 206.585
# INFO:tensorflow:step = 23001, loss = 0.000191284 (0.485 sec)
# INFO:tensorflow:global_step/sec: 220.129
# INFO:tensorflow:step = 23101, loss = 0.000111475 (0.453 sec)
# INFO:tensorflow:global_step/sec: 217.099
# INFO:tensorflow:step = 23201, loss = 0.00054942 (0.461 sec)
# INFO:tensorflow:global_step/sec: 218.516
# INFO:tensorflow:step = 23301, loss = 0.000662103 (0.457 sec)
# INFO:tensorflow:global_step/sec: 219.632
# INFO:tensorflow:step = 23401, loss = 0.00030255 (0.457 sec)
# INFO:tensorflow:global_step/sec: 215.735
# INFO:tensorflow:step = 23501, loss = 0.000680961 (0.463 sec)
# INFO:tensorflow:global_step/sec: 206.725
# INFO:tensorflow:step = 23601, loss = 0.000564568 (0.483 sec)
# INFO:tensorflow:global_step/sec: 212.864
# INFO:tensorflow:step = 23701, loss = 0.000314062 (0.470 sec)
# INFO:tensorflow:global_step/sec: 210.85
# INFO:tensorflow:step = 23801, loss = 0.000371108 (0.474 sec)
# INFO:tensorflow:global_step/sec: 215.804
# INFO:tensorflow:step = 23901, loss = 0.000671617 (0.463 sec)
# INFO:tensorflow:global_step/sec: 202.921
# INFO:tensorflow:step = 24001, loss = 8.61438e-05 (0.493 sec)
# INFO:tensorflow:global_step/sec: 207.157
# INFO:tensorflow:step = 24101, loss = 0.00102072 (0.483 sec)
# INFO:tensorflow:global_step/sec: 210.825
# INFO:tensorflow:step = 24201, loss = 0.000203232 (0.475 sec)
# INFO:tensorflow:global_step/sec: 203.553
# INFO:tensorflow:step = 24301, loss = 0.000594839 (0.491 sec)
# INFO:tensorflow:global_step/sec: 211.322
# INFO:tensorflow:step = 24401, loss = 0.00125343 (0.473 sec)
# INFO:tensorflow:global_step/sec: 217.873
# INFO:tensorflow:step = 24501, loss = 0.000587595 (0.459 sec)
# INFO:tensorflow:global_step/sec: 217.831
# INFO:tensorflow:step = 24601, loss = 0.000676824 (0.458 sec)
# INFO:tensorflow:global_step/sec: 213.002
# INFO:tensorflow:step = 24701, loss = 0.000170482 (0.469 sec)
# INFO:tensorflow:global_step/sec: 199.742
# INFO:tensorflow:step = 24801, loss = 0.000486355 (0.501 sec)
# INFO:tensorflow:global_step/sec: 197.327
# INFO:tensorflow:step = 24901, loss = 0.000508091 (0.507 sec)
# INFO:tensorflow:global_step/sec: 197.005
# INFO:tensorflow:step = 25001, loss = 0.000167062 (0.508 sec)
# INFO:tensorflow:global_step/sec: 203.149
# INFO:tensorflow:step = 25101, loss = 0.000222904 (0.492 sec)
# INFO:tensorflow:global_step/sec: 206.394
# INFO:tensorflow:step = 25201, loss = 0.000417549 (0.484 sec)
# INFO:tensorflow:global_step/sec: 213.108
# INFO:tensorflow:step = 25301, loss = 0.000390415 (0.469 sec)
# INFO:tensorflow:global_step/sec: 214.919
# INFO:tensorflow:step = 25401, loss = 7.45799e-05 (0.465 sec)
# INFO:tensorflow:global_step/sec: 214.477
# INFO:tensorflow:step = 25501, loss = 0.000767406 (0.466 sec)
# INFO:tensorflow:global_step/sec: 216.805
# INFO:tensorflow:step = 25601, loss = 0.00047697 (0.461 sec)
# INFO:tensorflow:global_step/sec: 201.5
# INFO:tensorflow:step = 25701, loss = 0.000169376 (0.497 sec)
# INFO:tensorflow:global_step/sec: 201.875
# INFO:tensorflow:step = 25801, loss = 0.000418528 (0.494 sec)
# INFO:tensorflow:global_step/sec: 221.917
# INFO:tensorflow:step = 25901, loss = 0.000143377 (0.453 sec)
# INFO:tensorflow:global_step/sec: 217.321
# INFO:tensorflow:step = 26001, loss = 0.000146161 (0.458 sec)
# INFO:tensorflow:global_step/sec: 219.346
# INFO:tensorflow:step = 26101, loss = 0.000213729 (0.456 sec)
# INFO:tensorflow:global_step/sec: 216.741
# INFO:tensorflow:step = 26201, loss = 0.000702149 (0.461 sec)
# INFO:tensorflow:global_step/sec: 213.006
# INFO:tensorflow:step = 26301, loss = 7.39427e-05 (0.470 sec)
# INFO:tensorflow:global_step/sec: 190.503
# INFO:tensorflow:step = 26401, loss = 0.000345016 (0.525 sec)
# INFO:tensorflow:global_step/sec: 208.519
# INFO:tensorflow:step = 26501, loss = 0.000584472 (0.481 sec)
# INFO:tensorflow:global_step/sec: 215.399
# INFO:tensorflow:step = 26601, loss = 0.000484585 (0.464 sec)
# INFO:tensorflow:global_step/sec: 212.9
# INFO:tensorflow:step = 26701, loss = 0.000101961 (0.470 sec)
# INFO:tensorflow:global_step/sec: 213.287
# INFO:tensorflow:step = 26801, loss = 0.000240875 (0.468 sec)
# INFO:tensorflow:global_step/sec: 214.776
# INFO:tensorflow:step = 26901, loss = 0.000375003 (0.466 sec)
# INFO:tensorflow:global_step/sec: 196.911
# INFO:tensorflow:step = 27001, loss = 0.00116218 (0.508 sec)
# INFO:tensorflow:global_step/sec: 216.121
# INFO:tensorflow:step = 27101, loss = 0.00122028 (0.463 sec)
# INFO:tensorflow:global_step/sec: 214.794
# INFO:tensorflow:step = 27201, loss = 0.000781832 (0.465 sec)
# INFO:tensorflow:global_step/sec: 207.072
# INFO:tensorflow:step = 27301, loss = 0.000244534 (0.483 sec)
# INFO:tensorflow:global_step/sec: 210.309
# INFO:tensorflow:step = 27401, loss = 0.000219884 (0.475 sec)
# INFO:tensorflow:global_step/sec: 213.883
# INFO:tensorflow:step = 27501, loss = 0.000127235 (0.468 sec)
# INFO:tensorflow:global_step/sec: 215.28
# INFO:tensorflow:step = 27601, loss = 0.000101455 (0.464 sec)
# INFO:tensorflow:global_step/sec: 205.898
# INFO:tensorflow:step = 27701, loss = 0.000117736 (0.486 sec)
# INFO:tensorflow:global_step/sec: 216.159
# INFO:tensorflow:step = 27801, loss = 0.000131664 (0.463 sec)
# INFO:tensorflow:global_step/sec: 215.549
# INFO:tensorflow:step = 27901, loss = 0.000644731 (0.464 sec)
# INFO:tensorflow:global_step/sec: 214.848
# INFO:tensorflow:step = 28001, loss = 0.000606445 (0.465 sec)
# INFO:tensorflow:global_step/sec: 209.853
# INFO:tensorflow:step = 28101, loss = 0.000919414 (0.477 sec)
# INFO:tensorflow:global_step/sec: 212.066
# INFO:tensorflow:step = 28201, loss = 0.00114571 (0.472 sec)
# INFO:tensorflow:global_step/sec: 211.556
# INFO:tensorflow:step = 28301, loss = 0.000599027 (0.473 sec)
# INFO:tensorflow:global_step/sec: 165.266
# INFO:tensorflow:step = 28401, loss = 0.000617068 (0.606 sec)
# INFO:tensorflow:global_step/sec: 212.91
# INFO:tensorflow:step = 28501, loss = 0.000565686 (0.468 sec)
# INFO:tensorflow:global_step/sec: 213.49
# INFO:tensorflow:step = 28601, loss = 0.000370941 (0.468 sec)
# INFO:tensorflow:global_step/sec: 205.362
# INFO:tensorflow:step = 28701, loss = 0.000182291 (0.488 sec)
# INFO:tensorflow:global_step/sec: 201.41
# INFO:tensorflow:step = 28801, loss = 0.000751365 (0.496 sec)
# INFO:tensorflow:global_step/sec: 218.803
# INFO:tensorflow:step = 28901, loss = 0.000272325 (0.457 sec)
# INFO:tensorflow:global_step/sec: 213.511
# INFO:tensorflow:step = 29001, loss = 0.000199587 (0.467 sec)
# INFO:tensorflow:global_step/sec: 213.38
# INFO:tensorflow:step = 29101, loss = 0.00062937 (0.469 sec)
# INFO:tensorflow:global_step/sec: 211.218
# INFO:tensorflow:step = 29201, loss = 0.00160454 (0.474 sec)
# INFO:tensorflow:global_step/sec: 219.404
# INFO:tensorflow:step = 29301, loss = 0.0003826 (0.456 sec)
# INFO:tensorflow:global_step/sec: 209.668
# INFO:tensorflow:step = 29401, loss = 0.000347731 (0.477 sec)
# INFO:tensorflow:global_step/sec: 207.542
# INFO:tensorflow:step = 29501, loss = 0.000156793 (0.482 sec)
# INFO:tensorflow:global_step/sec: 204.197
# INFO:tensorflow:step = 29601, loss = 0.000204107 (0.490 sec)
# INFO:tensorflow:global_step/sec: 206.669
# INFO:tensorflow:step = 29701, loss = 0.000507305 (0.484 sec)
# INFO:tensorflow:global_step/sec: 217.827
# INFO:tensorflow:step = 29801, loss = 7.69561e-05 (0.459 sec)
# INFO:tensorflow:global_step/sec: 212.147
# INFO:tensorflow:step = 29901, loss = 5.9902e-05 (0.471 sec)
# INFO:tensorflow:global_step/sec: 219.984
# INFO:tensorflow:step = 30001, loss = 0.000171886 (0.455 sec)
# INFO:tensorflow:global_step/sec: 215.162
# INFO:tensorflow:step = 30101, loss = 0.00034794 (0.465 sec)
# INFO:tensorflow:global_step/sec: 214.957
# INFO:tensorflow:step = 30201, loss = 0.000461018 (0.465 sec)
# INFO:tensorflow:global_step/sec: 216.586
# INFO:tensorflow:step = 30301, loss = 0.000102465 (0.462 sec)
# INFO:tensorflow:global_step/sec: 219.025
# INFO:tensorflow:step = 30401, loss = 0.00021223 (0.457 sec)
# INFO:tensorflow:global_step/sec: 218.121
# INFO:tensorflow:step = 30501, loss = 0.0001252 (0.458 sec)
# INFO:tensorflow:global_step/sec: 207.613
# INFO:tensorflow:step = 30601, loss = 0.000330342 (0.482 sec)
# INFO:tensorflow:global_step/sec: 204.999
# INFO:tensorflow:step = 30701, loss = 4.37102e-05 (0.488 sec)
# INFO:tensorflow:global_step/sec: 211.854
# INFO:tensorflow:step = 30801, loss = 0.000270311 (0.473 sec)
# INFO:tensorflow:global_step/sec: 221.955
# INFO:tensorflow:step = 30901, loss = 0.000127357 (0.449 sec)
# INFO:tensorflow:global_step/sec: 204.518
# INFO:tensorflow:step = 31001, loss = 0.000483889 (0.489 sec)
# INFO:tensorflow:global_step/sec: 217.741
# INFO:tensorflow:step = 31101, loss = 0.000220102 (0.459 sec)
# INFO:tensorflow:global_step/sec: 220.378
# INFO:tensorflow:step = 31201, loss = 0.000465531 (0.454 sec)
# INFO:tensorflow:global_step/sec: 209.398
# INFO:tensorflow:step = 31301, loss = 0.000664441 (0.478 sec)
# INFO:tensorflow:global_step/sec: 215.506
# INFO:tensorflow:step = 31401, loss = 0.000358667 (0.464 sec)
# INFO:tensorflow:global_step/sec: 218.797
# INFO:tensorflow:step = 31501, loss = 0.000124776 (0.457 sec)
# INFO:tensorflow:global_step/sec: 219.519
# INFO:tensorflow:step = 31601, loss = 0.000302122 (0.456 sec)
# INFO:tensorflow:global_step/sec: 211.972
# INFO:tensorflow:step = 31701, loss = 5.63435e-05 (0.473 sec)
# INFO:tensorflow:global_step/sec: 206.213
# INFO:tensorflow:step = 31801, loss = 0.000437563 (0.484 sec)
# INFO:tensorflow:global_step/sec: 211.647
# INFO:tensorflow:step = 31901, loss = 0.000518643 (0.473 sec)
# INFO:tensorflow:global_step/sec: 201.413
# INFO:tensorflow:step = 32001, loss = 0.000601506 (0.497 sec)
# INFO:tensorflow:global_step/sec: 212.052
# INFO:tensorflow:step = 32101, loss = 0.000650837 (0.471 sec)
# INFO:tensorflow:global_step/sec: 218.644
# INFO:tensorflow:step = 32201, loss = 0.000522681 (0.457 sec)
# INFO:tensorflow:global_step/sec: 217.154
# INFO:tensorflow:step = 32301, loss = 0.000546004 (0.460 sec)
# INFO:tensorflow:global_step/sec: 205.628
# INFO:tensorflow:step = 32401, loss = 0.000205861 (0.486 sec)
# INFO:tensorflow:global_step/sec: 212.28
# INFO:tensorflow:step = 32501, loss = 0.000271836 (0.471 sec)
# INFO:tensorflow:global_step/sec: 212.381
# INFO:tensorflow:step = 32601, loss = 0.00015307 (0.471 sec)
# INFO:tensorflow:global_step/sec: 217.975
# INFO:tensorflow:step = 32701, loss = 0.000214725 (0.459 sec)
# INFO:tensorflow:global_step/sec: 195.84
# INFO:tensorflow:step = 32801, loss = 0.000321945 (0.510 sec)
# INFO:tensorflow:global_step/sec: 213.677
# INFO:tensorflow:step = 32901, loss = 0.000109126 (0.468 sec)
# INFO:tensorflow:global_step/sec: 212.572
# INFO:tensorflow:step = 33001, loss = 0.000531671 (0.472 sec)
# INFO:tensorflow:global_step/sec: 215.318
# INFO:tensorflow:step = 33101, loss = 0.000373609 (0.463 sec)
# INFO:tensorflow:global_step/sec: 223.469
# INFO:tensorflow:step = 33201, loss = 0.000392586 (0.448 sec)
# INFO:tensorflow:global_step/sec: 216.839
# INFO:tensorflow:step = 33301, loss = 0.000222049 (0.463 sec)
# INFO:tensorflow:global_step/sec: 213.096
# INFO:tensorflow:step = 33401, loss = 0.00010267 (0.468 sec)
# INFO:tensorflow:global_step/sec: 214.259
# INFO:tensorflow:step = 33501, loss = 0.000474001 (0.467 sec)
# INFO:tensorflow:global_step/sec: 223.388
# INFO:tensorflow:step = 33601, loss = 0.00044351 (0.448 sec)
# INFO:tensorflow:global_step/sec: 206.511
# INFO:tensorflow:step = 33701, loss = 0.00034061 (0.484 sec)
# INFO:tensorflow:global_step/sec: 225.81
# INFO:tensorflow:step = 33801, loss = 0.000294845 (0.443 sec)
# INFO:tensorflow:global_step/sec: 214.879
# INFO:tensorflow:step = 33901, loss = 0.000273341 (0.465 sec)
# INFO:tensorflow:global_step/sec: 213.679
# INFO:tensorflow:step = 34001, loss = 0.000635406 (0.469 sec)
# INFO:tensorflow:global_step/sec: 208.975
# INFO:tensorflow:step = 34101, loss = 0.000124831 (0.478 sec)
# INFO:tensorflow:global_step/sec: 191.645
# INFO:tensorflow:step = 34201, loss = 0.000106118 (0.522 sec)
# INFO:tensorflow:global_step/sec: 213.671
# INFO:tensorflow:step = 34301, loss = 4.15599e-05 (0.467 sec)
# INFO:tensorflow:global_step/sec: 209.942
# INFO:tensorflow:step = 34401, loss = 0.000369877 (0.476 sec)
# INFO:tensorflow:global_step/sec: 215.507
# INFO:tensorflow:step = 34501, loss = 0.000219815 (0.464 sec)
# INFO:tensorflow:global_step/sec: 219.153
# INFO:tensorflow:step = 34601, loss = 0.000475048 (0.457 sec)
# INFO:tensorflow:global_step/sec: 213.303
# INFO:tensorflow:step = 34701, loss = 0.000263061 (0.469 sec)
# INFO:tensorflow:global_step/sec: 210.073
# INFO:tensorflow:step = 34801, loss = 0.00017794 (0.476 sec)
# INFO:tensorflow:global_step/sec: 213.663
# INFO:tensorflow:step = 34901, loss = 0.000179271 (0.467 sec)
# INFO:tensorflow:global_step/sec: 219.817
# INFO:tensorflow:step = 35001, loss = 0.000237827 (0.457 sec)
# INFO:tensorflow:global_step/sec: 204.334
# INFO:tensorflow:step = 35101, loss = 0.000252795 (0.487 sec)
# INFO:tensorflow:global_step/sec: 217.414
# INFO:tensorflow:step = 35201, loss = 0.000487789 (0.460 sec)
# INFO:tensorflow:global_step/sec: 217.373
# INFO:tensorflow:step = 35301, loss = 0.000311915 (0.460 sec)
# INFO:tensorflow:global_step/sec: 225.019
# INFO:tensorflow:step = 35401, loss = 9.289e-05 (0.444 sec)
# INFO:tensorflow:global_step/sec: 212.482
# INFO:tensorflow:step = 35501, loss = 3.6916e-05 (0.471 sec)
# INFO:tensorflow:global_step/sec: 210.212
# INFO:tensorflow:step = 35601, loss = 0.00033575 (0.476 sec)
# INFO:tensorflow:global_step/sec: 214.352
# INFO:tensorflow:step = 35701, loss = 0.000201156 (0.467 sec)
# INFO:tensorflow:global_step/sec: 217.459
# INFO:tensorflow:step = 35801, loss = 9.02326e-05 (0.460 sec)
# INFO:tensorflow:global_step/sec: 212.231
# INFO:tensorflow:step = 35901, loss = 0.000335693 (0.472 sec)
# INFO:tensorflow:global_step/sec: 207.647
# INFO:tensorflow:step = 36001, loss = 0.000226366 (0.482 sec)
# INFO:tensorflow:global_step/sec: 206.005
# INFO:tensorflow:step = 36101, loss = 9.51963e-05 (0.485 sec)
# INFO:tensorflow:global_step/sec: 212.669
# INFO:tensorflow:step = 36201, loss = 0.000223917 (0.470 sec)
# INFO:tensorflow:global_step/sec: 214.895
# INFO:tensorflow:step = 36301, loss = 0.00023966 (0.465 sec)
# INFO:tensorflow:global_step/sec: 200.133
# INFO:tensorflow:step = 36401, loss = 3.16189e-05 (0.500 sec)
# INFO:tensorflow:global_step/sec: 214.549
# INFO:tensorflow:step = 36501, loss = 0.000173767 (0.467 sec)
# INFO:tensorflow:global_step/sec: 211.362
# INFO:tensorflow:step = 36601, loss = 0.000163538 (0.472 sec)
# INFO:tensorflow:global_step/sec: 212.163
# INFO:tensorflow:step = 36701, loss = 9.66497e-05 (0.473 sec)
# INFO:tensorflow:global_step/sec: 211.925
# INFO:tensorflow:step = 36801, loss = 0.000216344 (0.471 sec)
# INFO:tensorflow:global_step/sec: 226.792
# INFO:tensorflow:step = 36901, loss = 7.88658e-05 (0.441 sec)
# INFO:tensorflow:global_step/sec: 198.77
# INFO:tensorflow:step = 37001, loss = 0.000115814 (0.503 sec)
# INFO:tensorflow:global_step/sec: 211.648
# INFO:tensorflow:step = 37101, loss = 0.000770587 (0.472 sec)
# INFO:tensorflow:global_step/sec: 204.865
# INFO:tensorflow:step = 37201, loss = 0.000268194 (0.488 sec)
# INFO:tensorflow:global_step/sec: 207.86
# INFO:tensorflow:step = 37301, loss = 0.000212393 (0.481 sec)
# INFO:tensorflow:global_step/sec: 215.915
# INFO:tensorflow:step = 37401, loss = 0.000730187 (0.463 sec)
# INFO:tensorflow:global_step/sec: 194.088
# INFO:tensorflow:step = 37501, loss = 0.000164754 (0.515 sec)
# INFO:tensorflow:global_step/sec: 200.069
# INFO:tensorflow:step = 37601, loss = 0.000528866 (0.501 sec)
# INFO:tensorflow:global_step/sec: 191.403
# INFO:tensorflow:step = 37701, loss = 0.000218112 (0.522 sec)
# INFO:tensorflow:global_step/sec: 203.825
# INFO:tensorflow:step = 37801, loss = 0.000438818 (0.490 sec)
# INFO:tensorflow:global_step/sec: 213.407
# INFO:tensorflow:step = 37901, loss = 0.00026111 (0.468 sec)
# INFO:tensorflow:global_step/sec: 212.963
# INFO:tensorflow:step = 38001, loss = 0.000801665 (0.470 sec)
# INFO:tensorflow:global_step/sec: 208.651
# INFO:tensorflow:step = 38101, loss = 0.000296692 (0.479 sec)
# INFO:tensorflow:global_step/sec: 216.391
# INFO:tensorflow:step = 38201, loss = 0.000453206 (0.462 sec)
# INFO:tensorflow:global_step/sec: 216.298
# INFO:tensorflow:step = 38301, loss = 0.000123386 (0.462 sec)
# INFO:tensorflow:global_step/sec: 215.646
# INFO:tensorflow:step = 38401, loss = 0.000341227 (0.464 sec)
# INFO:tensorflow:global_step/sec: 211.052
# INFO:tensorflow:step = 38501, loss = 0.000501349 (0.474 sec)
# INFO:tensorflow:global_step/sec: 216.114
# INFO:tensorflow:step = 38601, loss = 7.9525e-05 (0.464 sec)
# INFO:tensorflow:global_step/sec: 217.622
# INFO:tensorflow:step = 38701, loss = 9.35894e-05 (0.458 sec)
# INFO:tensorflow:global_step/sec: 215.146
# INFO:tensorflow:step = 38801, loss = 0.000341605 (0.465 sec)
# INFO:tensorflow:global_step/sec: 209.318
# INFO:tensorflow:step = 38901, loss = 0.00028871 (0.478 sec)
# INFO:tensorflow:global_step/sec: 207.395
# INFO:tensorflow:step = 39001, loss = 0.000365051 (0.483 sec)
# INFO:tensorflow:global_step/sec: 195.676
# INFO:tensorflow:step = 39101, loss = 0.000159492 (0.512 sec)
# INFO:tensorflow:global_step/sec: 213.591
# INFO:tensorflow:step = 39201, loss = 0.000437824 (0.467 sec)
# INFO:tensorflow:global_step/sec: 213.678
# INFO:tensorflow:step = 39301, loss = 5.73668e-05 (0.468 sec)
# INFO:tensorflow:global_step/sec: 225.335
# INFO:tensorflow:step = 39401, loss = 0.000280119 (0.444 sec)
# INFO:tensorflow:global_step/sec: 213.195
# INFO:tensorflow:step = 39501, loss = 0.000231113 (0.469 sec)
# INFO:tensorflow:global_step/sec: 213.409
# INFO:tensorflow:step = 39601, loss = 0.000301454 (0.469 sec)
# INFO:tensorflow:global_step/sec: 220.08
# INFO:tensorflow:step = 39701, loss = 1.09665e-05 (0.456 sec)
# INFO:tensorflow:global_step/sec: 209.712
# INFO:tensorflow:step = 39801, loss = 0.000178079 (0.475 sec)
# INFO:tensorflow:global_step/sec: 212.581
# INFO:tensorflow:step = 39901, loss = 5.097e-05 (0.472 sec)
# INFO:tensorflow:Saving checkpoints for 40000 into /tmp/tmp9jmnril0/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.000254309.
# DNNClassifier(params={'hidden_units': [300, 100], 'head': <tensorflow.contrib.learn.python.learn.estimators.head._MultiClassHead object at 0x7f48c0dfa4e0>, 'input_layer_min_slice_size': None, 'feature_columns': (_RealValuedColumn(column_name='', dimension=784, default_value=None, dtype=tf.float64, normalizer=None),), 'gradient_clip_norm': None, 'dropout': None, 'activation_fn': <function relu at 0x7f48d142e950>, 'optimizer': None, 'embedding_lr_multipliers': None})

# %%
from sklearn.metrics import accuracy_score
predict_target = list(dnn_clf.predict_classes(test_data))
accuracy_score(test_target, predict_target)

# %%
from sklearn.metrics import accuracy_score
predict_target = list(dnn_clf.predict(test_data))
accuracy_score(test_target, predict_target)

# %% [markdown]
# ### Hyperparameters
#
# __Number of hidden layers__
#
# > deep networks have a much higher parameter efficiency than shallow ones: they can model complex functions using exponentially fewer neurons than shallow nets, making them much faster to train
#
# > Real-world data is often ... hierarchical.
# - earlier hidden layers model low-level structures
# - intermediate hidden layers combine these low-level structures to model intermediate-level structures
# - later hidden layers (and the output layer) combine these intermediate structures to model high-level structures
#
# > In general you will get more bang for the buck by increasing the number of layers than the number of neurons per layer.
#
# __Number of neurons per layer__
#
# > a common practice is to size them ... with fewer and fewer neurons at each layer
#
# It is also common practice to make set the same number of neurons in each layer.
#
# __Activation functions__
#
# ReLU is a good/common choice.
#
# > For the output layer, the softmax activation function is generally a good choice for classification tasks (when the classes are mutually exclusive). For regression tasks, you can simply use no activation function at all.
