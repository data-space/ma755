# %% [markdown]
# ### MA755 Machine Learning - Chapter 10. Introduction to Artificial Neural Networks - 2 May 2017
#
# These notes are based on, and include images from, [_Hands-On Machine Learning with Scikit-Learn and TensorFlow_](http://shop.oreilly.com/product/0636920052289.do) by Aurélien Géron, published by O'Reilly Media, Inc., 2017

# %%
# !pip install tensorflow --quiet
# Out:
# Collecting tensorflow
#   Downloading tensorflow-1.1.0-cp35-cp35m-manylinux1_x86_64.whl (31.0MB)
#     100% |████████████████████████████████| 31.0MB 46kB/s  eta 0:00:01  6% |██▏                             | 2.1MB 10.2MB/s eta 0:00:03    16% |█████▍                          | 5.2MB 26.7MB/s eta 0:00:01    62% |████████████████████            | 19.5MB 29.5MB/s eta 0:00:01
# Requirement already satisfied (use --upgrade to upgrade): wheel>=0.26 in /opt/conda/lib/python3.5/site-packages (from tensorflow)
# Requirement already satisfied (use --upgrade to upgrade): six>=1.10.0 in /opt/conda/lib/python3.5/site-packages (from tensorflow)
# Requirement already satisfied (use --upgrade to upgrade): numpy>=1.11.0 in /opt/conda/lib/python3.5/site-packages (from tensorflow)
# Collecting werkzeug>=0.11.10 (from tensorflow)
#   Downloading Werkzeug-0.12.1-py2.py3-none-any.whl (312kB)
#     100% |████████████████████████████████| 317kB 1.4MB/s eta 0:00:01
# Collecting protobuf>=3.2.0 (from tensorflow)
#   Downloading protobuf-3.2.0-cp35-cp35m-manylinux1_x86_64.whl (5.6MB)
#     100% |████████████████████████████████| 5.6MB 293kB/s eta 0:00:01
# Requirement already satisfied (use --upgrade to upgrade): setuptools in /opt/conda/lib/python3.5/site-packages/setuptools-27.2.0-py3.5.egg (from protobuf>=3.2.0->tensorflow)
# Installing collected packages: werkzeug, protobuf, tensorflow
# Successfully installed protobuf-3.2.0 tensorflow-1.1.0 werkzeug-0.12.1
# You are using pip version 8.1.2, however version 9.0.1 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %%
import tensorflow as tf
import numpy      as np

# %% [markdown]
# The basic building block of a neural network is a _linear threshold unit_ (LTU.)
#
# In practice the step function is not the heaviside function, but it is included below to demonstrate the origins of the LTU.

# %% [markdown]
# ###  Linear Threshold Unit (LTU)
#
# A _linear threshold unit_ is defined with:
#
# - _weights_: $\textbf{w}=w_1, w_2, ..., w_m$
# - _input_: $\textbf{x}=x_1, x_2, ..., x_m$ (a vector of independent variable values, for a row)
# - _output_: $\operatorname{step}({w}^{T}\cdot\textbf{x})=\operatorname{step}(w_1 x_1 + w_2 x_2, ..., w_n x_m)$
#
# where the most common step function is the heaviside function:
# \begin{align}
# \operatorname{heaviside}(z) = 0 & \text{ if } z < 0
# \\                          = 1 & \text{ if } z \ge 0
# \end{align}

# %% [markdown]
# ![alt](LTU.png)
# Source: Hands-On Machine Learning with Scikit-Learn and TensorFlow by Aurélien Géron

# %% [markdown]
# __Notice that the weights are associated with the edges (or arrows.)__

# %% [markdown]
# ### Perceptron
#
# > A Perceptron is simply composed of a single layer of LTUs, with each neuron connected to all the inputs.
#
# In addition, each neuron is connected to all of the outputs.
#
# The perceptron `fit` method:
# - input: a 2D numpy array of shape `(n_samples, n_features()`
# - input: a 1D numpy array of shape `(n_samples,)`
# - output: multiple binary values (multioutput)
#
# The following code is a mini-example of the `Perceptron` function.

# %%
from sklearn.datasets     import load_iris
from sklearn.linear_model import Perceptron

iris = load_iris()
X = iris.data[:, (2, 3)]  # petal length, petal width
y = (iris.target == 0).astype(np.int)  # Iris Setosa?

per_clf = Perceptron(random_state=42)
per_clf.fit(X, y)

y_pred = per_clf.predict([[2, 0.5]])
y_pred
# Out:
# array([1])

# %% [markdown]
# The perceptron model is graphically displayed below.

# %% [markdown]
# ![alt](perceptron.png)
# Source: Hands-On Machine Learning with Scikit-Learn and TensorFlow by Aurélien Géron

# %% [markdown]
# ### Perceptron learning rule (weight update)
#
# The network is a flow chart which takes input values to output values. The arrows and their weights determine the output(s) for each set of inputs.
#
# Below the weight $w_{i,j}$ is the arrow between the $i$-th input neuron and the $j$-th output neuron. This and other details are listed below.

# %% [markdown]
# ![alt](perceptronlearningrule.png)

# %% [markdown]
# Where:
# - $w_{i, j}$ is the connection weight between the $i$-th input neuron and the $j$-th output neuron
# - $x_i$ is the ith input value of the current training instance
# - $\hat{y}_j$ is the predicted output of the $j$-th output neuron for the current training instance
# - $y_j$ is the target output of the $j$-th output neuron for the current training instance
# - $\eta$ is the learning rate
#
# Assuming that the learning rate is positive (in the text it is set to `1`) I believe the expression $\hat{y}_j - y_j$ from the text (above) should be reversed.
#
# Exercise: Check this. See also [Perceptron at Wikipedia](https://en.wikipedia.org/wiki/Perceptron).

# %% [markdown]
# ### Replacing the step function
#
# The step function only returns two values (`0` and `1`), its derivative is zero everywhere and so the gradient is not useful.

# %% [markdown]
# For these reasons it is replaced with an __activation function__, such as one of the logistic/sigmoid, hyperbolic tangent or ReLU functions.
#
# Sigmoid function:
# $$\sigma(z) = \frac{1}{1 + e^{(-z)}}
# $$
#
# Hypbolic tangent function:
# $$\tanh(z) =  2\sigma(2z) – 1
# $$
#
# ReLU function:
# $$\operatorname{ReLU}(z) = \max(0,z)
# $$
#
# In practice the ReLU function is used most often.
#
# These three functions and their derivatives are displayed below.

# %% [markdown]
# ![alt](derivatives.png)

# %% [markdown]
# ### Softmax
#
# When a neural network is used for classification and the number of classes predicted is greater than two, then the softmax function can provide, for each instance, probabilities for each class that add to `1`.
#
# The softmax function has $K$ input values $z_j$ for $j=1, ..., K$ and $K$ output values
# $$
#     \sigma(z)_j = \frac{e^{z_j}}{\sum_{k=1}^K e^{z_k}}
# $$
# for $j=1, ..., K$ where $K$ is usually the number of classes of the target variable.
#
# These output values are interpreted as probabilities.
#
# See [Softmax at Wikipedia](https://en.wikipedia.org/wiki/Softmax_function).

# %% [markdown]
# ![alt](softmax.png)

# %% [markdown]
# ### Multi-Layer Perceptron (MLP)
#
# A MLP consists of multiple layers of LTUs. See graphic below.

# %% [markdown]
# ![alt](mlp.png)

# %% [markdown]
# > For each training instance,
# 1. the algorithm feeds it to the network and computes the output of every neuron in each consecutive layer (this is the forward pass, just like when making predictions).
# 1. Then it measures the network’s output error (i.e., the difference between the desired output and the actual output of the network), and it computes how much each neuron in the last hidden layer contributed to each output neuron’s error.
# 1. It then proceeds to measure how much of these error contributions came from each neuron in the previous hidden layer—and so on until the algorithm reaches the input layer. This reverse pass efficiently measures the error gradient across all the connection weights in the network by propagating the error gradient backward in the network (hence the name of the algorithm).

# %% [markdown]
# ### Training Model
#
# > For each training instance the _backpropagation algorithm_ first makes a prediction (forward pass), measures the error, then goes through each layer in reverse to measure the error contribution from each connection (reverse pass), and finally slightly tweaks the connection weights to reduce the error (Gradient Descent step).
#
# 1. For each instance, feed its input values into the network and successively calculate each layer. The last layer calculates the prediction
# 1. Measure the error at each layer (in reverse order of the previous step)
# 1. Modify the weights to decrease the error (gradient descent)

# %% [markdown]
# ### Training Model - Backpropogation
#
# For a nicely worked out example, code and visualizations see:
# - https://mattmazur.com/2015/03/17/a-step-by-step-backpropagation-example/

# %% [markdown]
# ### The `sklearn` implementation of MLP
#
# - http://scikit-learn.org/stable/modules/neural_networks_supervised.html

# %% [markdown]
# ### Training an MLP with TensorFlow’s High-Level API
#
# Use function `DNNClassifier` from the `tensorflow.contrib.learn` class.

# %%
import pickle
mnist = pickle.load(open( "mnist.p", "rb" ))

# %%
print("mnist.data.shape  ", mnist.data.shape)
print("mnist.target.shape", mnist.target.shape)
# Out:
# mnist.data.shape   (70000, 784)
# mnist.target.shape (70000,)

# %%
from sklearn.preprocessing   import StandardScaler
mnist_data_scaled = StandardScaler().fit_transform(mnist.data.astype(float))

# %%
from sklearn.model_selection import train_test_split

mnist_data_scaled = StandardScaler().fit_transform(mnist.data.astype(float))
mnist_target      = mnist.target.astype(int)

(train_data,        test_data, 
 train_target,      test_target, 
) = train_test_split(mnist_data_scaled,
                     mnist_target,
                     test_size=0.2, 
                     random_state=42)

(train_data.shape,        test_data.shape, 
 train_target.shape,      test_target.shape,
)
# Out:
# ((56000, 784), (14000, 784), (56000,), (14000,))

# %%
import tensorflow as tf

feature_columns = tf.contrib.learn.infer_real_valued_columns_from_input(train_data)
dnn_clf = tf.contrib.learn.DNNClassifier(hidden_units=[300, 100], n_class
                                         es=10,
                                         feature_columns=feature_columns)
dnn_clf.fit(x=train_data, y=train_target, batch_size=50, steps=40000)
# Out:
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_tf_config': gpu_options {
#   per_process_gpu_memory_fraction: 1.0
# }
# , '_environment': 'local', '_num_ps_replicas': 0, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_model_dir': None, '_num_worker_replicas': 0, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f1fea8f10b8>, '_keep_checkpoint_every_n_hours': 10000, '_is_chief': True, '_tf_random_seed': None, '_save_summary_steps': 100, '_evaluation_master': '', '_task_type': None, '_keep_checkpoint_max': 5, '_master': '', '_task_id': 0}
# WARNING:tensorflow:Using temporary folder as model directory: /tmp/tmpncrcrp1x
# WARNING:tensorflow:From <ipython-input-19-327b84f10bbf>:6: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with y is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-19-327b84f10bbf>:6: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with batch_size is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:From <ipython-input-19-327b84f10bbf>:6: calling BaseEstimator.fit (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# /opt/conda/lib/python3.5/site-packages/tensorflow/python/util/deprecation.py:248: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   equality = a == b
# WARNING:tensorflow:From /opt/conda/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/estimators/head.py:615: scalar_summary (from tensorflow.python.ops.logging_ops) is deprecated and will be removed after 2016-11-30.
# Instructions for updating:
# Please switch to tf.summary.scalar. Note that tf.summary.scalar uses the node name instead of the tag. This means that TensorFlow will automatically de-duplicate summary names based on the scope they are created in. Also, passing a tensor or list of tags to a scalar summary op is no longer supported.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Saving checkpoints for 1 into /tmp/tmpncrcrp1x/model.ckpt.
# INFO:tensorflow:step = 1, loss = 2.87816
# INFO:tensorflow:global_step/sec: 128.948
# INFO:tensorflow:step = 101, loss = 0.202792 (0.777 sec)
# INFO:tensorflow:global_step/sec: 148.674
# INFO:tensorflow:step = 201, loss = 0.196656 (0.673 sec)
# INFO:tensorflow:global_step/sec: 177.962
# INFO:tensorflow:step = 301, loss = 0.343907 (0.561 sec)
# INFO:tensorflow:global_step/sec: 204.302
# INFO:tensorflow:step = 401, loss = 0.281701 (0.490 sec)
# INFO:tensorflow:global_step/sec: 205.828
# INFO:tensorflow:step = 501, loss = 0.314509 (0.486 sec)
# INFO:tensorflow:global_step/sec: 204.624
# INFO:tensorflow:step = 601, loss = 0.167086 (0.489 sec)
# INFO:tensorflow:global_step/sec: 204.956
# INFO:tensorflow:step = 701, loss = 0.105416 (0.489 sec)
# INFO:tensorflow:global_step/sec: 117.993
# INFO:tensorflow:step = 801, loss = 0.290069 (0.846 sec)
# INFO:tensorflow:global_step/sec: 162.233
# INFO:tensorflow:step = 901, loss = 0.0610391 (0.616 sec)
# INFO:tensorflow:global_step/sec: 178.844
# INFO:tensorflow:step = 1001, loss = 0.23799 (0.560 sec)
# INFO:tensorflow:global_step/sec: 192.301
# INFO:tensorflow:step = 1101, loss = 0.0509182 (0.519 sec)
# INFO:tensorflow:global_step/sec: 184.033
# INFO:tensorflow:step = 1201, loss = 0.0864558 (0.546 sec)
# INFO:tensorflow:global_step/sec: 211.491
# INFO:tensorflow:step = 1301, loss = 0.0323341 (0.470 sec)
# INFO:tensorflow:global_step/sec: 207.078
# INFO:tensorflow:step = 1401, loss = 0.0372462 (0.483 sec)
# INFO:tensorflow:global_step/sec: 210.137
# INFO:tensorflow:step = 1501, loss = 0.0724196 (0.476 sec)
# INFO:tensorflow:global_step/sec: 203.218
# INFO:tensorflow:step = 1601, loss = 0.0251276 (0.492 sec)
# INFO:tensorflow:global_step/sec: 210.276
# INFO:tensorflow:step = 1701, loss = 0.25 (0.476 sec)
# INFO:tensorflow:global_step/sec: 220.021
# INFO:tensorflow:step = 1801, loss = 0.0576132 (0.454 sec)
# INFO:tensorflow:global_step/sec: 214.851
# INFO:tensorflow:step = 1901, loss = 0.0522076 (0.469 sec)
# INFO:tensorflow:global_step/sec: 212.194
# INFO:tensorflow:step = 2001, loss = 0.0175096 (0.468 sec)
# INFO:tensorflow:global_step/sec: 215.82
# INFO:tensorflow:step = 2101, loss = 0.0807353 (0.464 sec)
# INFO:tensorflow:global_step/sec: 204.061
# INFO:tensorflow:step = 2201, loss = 0.0606192 (0.491 sec)
# INFO:tensorflow:global_step/sec: 215.582
# INFO:tensorflow:step = 2301, loss = 0.0278466 (0.464 sec)
# INFO:tensorflow:global_step/sec: 224.063
# INFO:tensorflow:step = 2401, loss = 0.0330053 (0.446 sec)
# INFO:tensorflow:global_step/sec: 213.862
# INFO:tensorflow:step = 2501, loss = 0.0114511 (0.466 sec)
# INFO:tensorflow:global_step/sec: 206.251
# INFO:tensorflow:step = 2601, loss = 0.076739 (0.485 sec)
# INFO:tensorflow:global_step/sec: 205.798
# INFO:tensorflow:step = 2701, loss = 0.0280053 (0.486 sec)
# INFO:tensorflow:global_step/sec: 151.082
# INFO:tensorflow:step = 2801, loss = 0.0345675 (0.664 sec)
# INFO:tensorflow:global_step/sec: 141.651
# INFO:tensorflow:step = 2901, loss = 0.0212025 (0.705 sec)
# INFO:tensorflow:global_step/sec: 196.838
# INFO:tensorflow:step = 3001, loss = 0.118736 (0.507 sec)
# INFO:tensorflow:global_step/sec: 195.275
# INFO:tensorflow:step = 3101, loss = 0.0354552 (0.512 sec)
# INFO:tensorflow:global_step/sec: 180.893
# INFO:tensorflow:step = 3201, loss = 0.0147577 (0.554 sec)
# INFO:tensorflow:global_step/sec: 213.005
# INFO:tensorflow:step = 3301, loss = 0.0291815 (0.469 sec)
# INFO:tensorflow:global_step/sec: 180.66
# INFO:tensorflow:step = 3401, loss = 0.0508078 (0.554 sec)
# INFO:tensorflow:global_step/sec: 192.326
# INFO:tensorflow:step = 3501, loss = 0.0337479 (0.520 sec)
# INFO:tensorflow:global_step/sec: 216.273
# INFO:tensorflow:step = 3601, loss = 0.0061563 (0.461 sec)
# INFO:tensorflow:global_step/sec: 199.149
# INFO:tensorflow:step = 3701, loss = 0.0145525 (0.502 sec)
# INFO:tensorflow:global_step/sec: 206.685
# INFO:tensorflow:step = 3801, loss = 0.0200048 (0.485 sec)
# INFO:tensorflow:global_step/sec: 183.43
# INFO:tensorflow:step = 3901, loss = 0.12672 (0.546 sec)
# INFO:tensorflow:global_step/sec: 161.286
# INFO:tensorflow:step = 4001, loss = 0.0158508 (0.621 sec)
# INFO:tensorflow:global_step/sec: 141.871
# INFO:tensorflow:step = 4101, loss = 0.0430343 (0.703 sec)
# INFO:tensorflow:global_step/sec: 119.431
# INFO:tensorflow:step = 4201, loss = 0.0237217 (0.839 sec)
# INFO:tensorflow:global_step/sec: 145.271
# INFO:tensorflow:step = 4301, loss = 0.0377119 (0.687 sec)
# INFO:tensorflow:global_step/sec: 169.862
# INFO:tensorflow:step = 4401, loss = 0.0918264 (0.591 sec)
# INFO:tensorflow:global_step/sec: 121.427
# INFO:tensorflow:step = 4501, loss = 0.0329162 (0.822 sec)
# INFO:tensorflow:global_step/sec: 129.509
# INFO:tensorflow:step = 4601, loss = 0.00484409 (0.773 sec)
# INFO:tensorflow:global_step/sec: 147.608
# INFO:tensorflow:step = 4701, loss = 0.0173977 (0.678 sec)
# INFO:tensorflow:global_step/sec: 205.094
# INFO:tensorflow:step = 4801, loss = 0.0200072 (0.486 sec)
# INFO:tensorflow:global_step/sec: 204.529
# INFO:tensorflow:step = 4901, loss = 0.0505565 (0.490 sec)
# INFO:tensorflow:global_step/sec: 209.812
# INFO:tensorflow:step = 5001, loss = 0.013076 (0.477 sec)
# INFO:tensorflow:global_step/sec: 216.052
# INFO:tensorflow:step = 5101, loss = 0.263678 (0.463 sec)
# INFO:tensorflow:global_step/sec: 197.508
# INFO:tensorflow:step = 5201, loss = 0.00758798 (0.507 sec)
# INFO:tensorflow:global_step/sec: 204.63
# INFO:tensorflow:step = 5301, loss = 0.00957789 (0.487 sec)
# INFO:tensorflow:global_step/sec: 211.243
# INFO:tensorflow:step = 5401, loss = 0.0694635 (0.473 sec)
# INFO:tensorflow:global_step/sec: 212.871
# INFO:tensorflow:step = 5501, loss = 0.00891399 (0.470 sec)
# INFO:tensorflow:global_step/sec: 224.288
# INFO:tensorflow:step = 5601, loss = 0.00403237 (0.446 sec)
# INFO:tensorflow:global_step/sec: 205.251
# INFO:tensorflow:step = 5701, loss = 0.0111614 (0.487 sec)
# INFO:tensorflow:global_step/sec: 218.729
# INFO:tensorflow:step = 5801, loss = 0.00510938 (0.458 sec)
# INFO:tensorflow:global_step/sec: 215.366
# INFO:tensorflow:step = 5901, loss = 0.00224587 (0.463 sec)
# INFO:tensorflow:global_step/sec: 131.811
# INFO:tensorflow:step = 6001, loss = 0.00955372 (0.760 sec)
# INFO:tensorflow:global_step/sec: 142.544
# INFO:tensorflow:step = 6101, loss = 0.0135833 (0.702 sec)
# INFO:tensorflow:global_step/sec: 184.431
# INFO:tensorflow:step = 6201, loss = 0.0005646 (0.543 sec)
# INFO:tensorflow:global_step/sec: 158.243
# INFO:tensorflow:step = 6301, loss = 0.0042744 (0.632 sec)
# INFO:tensorflow:global_step/sec: 185.867
# INFO:tensorflow:step = 6401, loss = 0.00395512 (0.536 sec)
# INFO:tensorflow:global_step/sec: 134.253
# INFO:tensorflow:step = 6501, loss = 0.0019796 (0.746 sec)
# INFO:tensorflow:global_step/sec: 204.512
# INFO:tensorflow:step = 6601, loss = 0.00950387 (0.492 sec)
# INFO:tensorflow:global_step/sec: 120.283
# INFO:tensorflow:step = 6701, loss = 0.00343266 (0.829 sec)
# INFO:tensorflow:global_step/sec: 167.909
# INFO:tensorflow:step = 6801, loss = 0.00607428 (0.596 sec)
# INFO:tensorflow:global_step/sec: 158.574
# INFO:tensorflow:step = 6901, loss = 0.00935204 (0.629 sec)
# INFO:tensorflow:global_step/sec: 172.442
# INFO:tensorflow:step = 7001, loss = 0.00468699 (0.580 sec)
# INFO:tensorflow:global_step/sec: 193.467
# INFO:tensorflow:step = 7101, loss = 0.00135027 (0.524 sec)
# INFO:tensorflow:global_step/sec: 154.522
# INFO:tensorflow:step = 7201, loss = 0.00386658 (0.641 sec)
# INFO:tensorflow:global_step/sec: 187.541
# INFO:tensorflow:step = 7301, loss = 0.00473048 (0.536 sec)
# INFO:tensorflow:global_step/sec: 148.833
# INFO:tensorflow:step = 7401, loss = 0.0016532 (0.668 sec)
# INFO:tensorflow:global_step/sec: 170.224
# INFO:tensorflow:step = 7501, loss = 0.00419364 (0.587 sec)
# INFO:tensorflow:global_step/sec: 147.4
# INFO:tensorflow:step = 7601, loss = 0.00348948 (0.679 sec)
# INFO:tensorflow:global_step/sec: 187.876
# INFO:tensorflow:step = 7701, loss = 0.000963448 (0.532 sec)
# INFO:tensorflow:global_step/sec: 134.452
# INFO:tensorflow:step = 7801, loss = 0.0112913 (0.745 sec)
# INFO:tensorflow:global_step/sec: 172.283
# INFO:tensorflow:step = 7901, loss = 0.00163109 (0.579 sec)
# INFO:tensorflow:global_step/sec: 148.293
# INFO:tensorflow:step = 8001, loss = 0.00938703 (0.674 sec)
# INFO:tensorflow:global_step/sec: 170.346
# INFO:tensorflow:step = 8101, loss = 0.000494918 (0.587 sec)
# INFO:tensorflow:global_step/sec: 181.937
# INFO:tensorflow:step = 8201, loss = 0.00480804 (0.552 sec)
# INFO:tensorflow:global_step/sec: 123.045
# INFO:tensorflow:step = 8301, loss = 0.00336707 (0.810 sec)
# INFO:tensorflow:global_step/sec: 163.915
# INFO:tensorflow:step = 8401, loss = 0.00143432 (0.610 sec)
# INFO:tensorflow:global_step/sec: 170.99
# INFO:tensorflow:step = 8501, loss = 0.00143488 (0.585 sec)
# INFO:tensorflow:global_step/sec: 200.884
# INFO:tensorflow:step = 8601, loss = 0.000616871 (0.498 sec)
# INFO:tensorflow:global_step/sec: 203.951
# INFO:tensorflow:step = 8701, loss = 0.000402541 (0.490 sec)
# INFO:tensorflow:global_step/sec: 194.912
# INFO:tensorflow:step = 8801, loss = 0.0153985 (0.515 sec)
# INFO:tensorflow:global_step/sec: 182.63
# INFO:tensorflow:step = 8901, loss = 0.0131088 (0.549 sec)
# INFO:tensorflow:global_step/sec: 183.936
# INFO:tensorflow:step = 9001, loss = 0.00257369 (0.543 sec)
# INFO:tensorflow:global_step/sec: 123.825
# INFO:tensorflow:step = 9101, loss = 0.00206118 (0.805 sec)
# INFO:tensorflow:global_step/sec: 169.467
# INFO:tensorflow:step = 9201, loss = 0.000529932 (0.590 sec)
# INFO:tensorflow:global_step/sec: 191.807
# INFO:tensorflow:step = 9301, loss = 0.000341274 (0.521 sec)
# INFO:tensorflow:global_step/sec: 203.259
# INFO:tensorflow:step = 9401, loss = 0.00270997 (0.492 sec)
# INFO:tensorflow:global_step/sec: 190.974
# INFO:tensorflow:step = 9501, loss = 0.00589693 (0.524 sec)
# INFO:tensorflow:global_step/sec: 187.486
# INFO:tensorflow:step = 9601, loss = 0.00216289 (0.533 sec)
# INFO:tensorflow:global_step/sec: 182.955
# INFO:tensorflow:step = 9701, loss = 0.000881827 (0.547 sec)
# INFO:tensorflow:global_step/sec: 198.008
# INFO:tensorflow:step = 9801, loss = 0.00441494 (0.505 sec)
# INFO:tensorflow:global_step/sec: 199.166
# INFO:tensorflow:step = 9901, loss = 0.00643321 (0.502 sec)
# INFO:tensorflow:global_step/sec: 195.203
# INFO:tensorflow:step = 10001, loss = 0.00336339 (0.512 sec)
# INFO:tensorflow:global_step/sec: 170.078
# INFO:tensorflow:step = 10101, loss = 0.00367304 (0.588 sec)
# INFO:tensorflow:global_step/sec: 153.525
# INFO:tensorflow:step = 10201, loss = 0.000639015 (0.651 sec)
# INFO:tensorflow:global_step/sec: 181.272
# INFO:tensorflow:step = 10301, loss = 0.00179116 (0.552 sec)
# INFO:tensorflow:global_step/sec: 158.333
# INFO:tensorflow:step = 10401, loss = 0.00203794 (0.633 sec)
# INFO:tensorflow:global_step/sec: 188.657
# INFO:tensorflow:step = 10501, loss = 0.000316666 (0.529 sec)
# INFO:tensorflow:global_step/sec: 110.602
# INFO:tensorflow:step = 10601, loss = 0.00114921 (0.904 sec)
# INFO:tensorflow:global_step/sec: 199.546
# INFO:tensorflow:step = 10701, loss = 0.00233814 (0.501 sec)
# INFO:tensorflow:global_step/sec: 142.452
# INFO:tensorflow:step = 10801, loss = 0.00257889 (0.712 sec)
# INFO:tensorflow:global_step/sec: 174.551
# INFO:tensorflow:step = 10901, loss = 0.00226818 (0.563 sec)
# INFO:tensorflow:global_step/sec: 202.786
# INFO:tensorflow:step = 11001, loss = 0.00167534 (0.493 sec)
# INFO:tensorflow:global_step/sec: 215.935
# INFO:tensorflow:step = 11101, loss = 0.000688009 (0.463 sec)
# INFO:tensorflow:global_step/sec: 202.053
# INFO:tensorflow:step = 11201, loss = 0.000587824 (0.495 sec)
# INFO:tensorflow:global_step/sec: 199.433
# INFO:tensorflow:step = 11301, loss = 0.00533293 (0.501 sec)
# INFO:tensorflow:global_step/sec: 223.457
# INFO:tensorflow:step = 11401, loss = 0.00220163 (0.450 sec)
# INFO:tensorflow:global_step/sec: 211.6
# INFO:tensorflow:step = 11501, loss = 0.00193539 (0.471 sec)
# INFO:tensorflow:global_step/sec: 207.079
# INFO:tensorflow:step = 11601, loss = 0.001313 (0.483 sec)
# INFO:tensorflow:global_step/sec: 184.819
# INFO:tensorflow:step = 11701, loss = 0.000798629 (0.543 sec)
# INFO:tensorflow:global_step/sec: 194.465
# INFO:tensorflow:step = 11801, loss = 0.000992381 (0.512 sec)
# INFO:tensorflow:global_step/sec: 196.295
# INFO:tensorflow:step = 11901, loss = 0.00162115 (0.510 sec)
# INFO:tensorflow:global_step/sec: 218.144
# INFO:tensorflow:step = 12001, loss = 0.00372524 (0.458 sec)
# INFO:tensorflow:global_step/sec: 179.59
# INFO:tensorflow:step = 12101, loss = 0.00439952 (0.557 sec)
# INFO:tensorflow:global_step/sec: 204.576
# INFO:tensorflow:step = 12201, loss = 0.000509975 (0.489 sec)
# INFO:tensorflow:global_step/sec: 171.086
# INFO:tensorflow:step = 12301, loss = 0.000757641 (0.584 sec)
# INFO:tensorflow:global_step/sec: 185.542
# INFO:tensorflow:step = 12401, loss = 0.000424293 (0.539 sec)
# INFO:tensorflow:global_step/sec: 132.763
# INFO:tensorflow:step = 12501, loss = 0.000691456 (0.755 sec)
# INFO:tensorflow:global_step/sec: 186.189
# INFO:tensorflow:step = 12601, loss = 0.00305167 (0.535 sec)
# INFO:tensorflow:global_step/sec: 196.556
# INFO:tensorflow:step = 12701, loss = 0.000823322 (0.509 sec)
# INFO:tensorflow:global_step/sec: 159.804
# INFO:tensorflow:step = 12801, loss = 0.000953691 (0.626 sec)
# INFO:tensorflow:global_step/sec: 196.192
# INFO:tensorflow:step = 12901, loss = 0.00486706 (0.510 sec)
# INFO:tensorflow:global_step/sec: 190.365
# INFO:tensorflow:step = 13001, loss = 0.000203242 (0.525 sec)
# INFO:tensorflow:global_step/sec: 206.975
# INFO:tensorflow:step = 13101, loss = 0.000197673 (0.483 sec)
# INFO:tensorflow:global_step/sec: 195.791
# INFO:tensorflow:step = 13201, loss = 0.0024185 (0.511 sec)
# INFO:tensorflow:global_step/sec: 177.442
# INFO:tensorflow:step = 13301, loss = 0.00118774 (0.565 sec)
# INFO:tensorflow:global_step/sec: 123.629
# INFO:tensorflow:step = 13401, loss = 0.000388273 (0.808 sec)
# INFO:tensorflow:global_step/sec: 125.19
# INFO:tensorflow:step = 13501, loss = 0.000323265 (0.799 sec)
# INFO:tensorflow:global_step/sec: 179.626
# INFO:tensorflow:step = 13601, loss = 8.78561e-05 (0.557 sec)
# INFO:tensorflow:global_step/sec: 195.033
# INFO:tensorflow:step = 13701, loss = 0.00378471 (0.512 sec)
# INFO:tensorflow:global_step/sec: 195.341
# INFO:tensorflow:step = 13801, loss = 0.000500706 (0.512 sec)
# INFO:tensorflow:global_step/sec: 198.397
# INFO:tensorflow:step = 13901, loss = 0.00050438 (0.504 sec)
# INFO:tensorflow:global_step/sec: 184.364
# INFO:tensorflow:step = 14001, loss = 0.00158067 (0.542 sec)
# INFO:tensorflow:global_step/sec: 179.92
# INFO:tensorflow:step = 14101, loss = 0.00105311 (0.556 sec)
# INFO:tensorflow:global_step/sec: 178.166
# INFO:tensorflow:step = 14201, loss = 0.00061688 (0.563 sec)
# INFO:tensorflow:global_step/sec: 177.341
# INFO:tensorflow:step = 14301, loss = 0.00105416 (0.563 sec)
# INFO:tensorflow:global_step/sec: 110.001
# INFO:tensorflow:step = 14401, loss = 0.000578564 (0.913 sec)
# INFO:tensorflow:global_step/sec: 123.328
# INFO:tensorflow:step = 14501, loss = 0.000574589 (0.805 sec)
# INFO:tensorflow:global_step/sec: 135.408
# INFO:tensorflow:step = 14601, loss = 0.000535803 (0.744 sec)
# INFO:tensorflow:global_step/sec: 188.716
# INFO:tensorflow:step = 14701, loss = 0.001169 (0.526 sec)
# INFO:tensorflow:global_step/sec: 85.9005
# INFO:tensorflow:step = 14801, loss = 0.00251282 (1.163 sec)
# INFO:tensorflow:global_step/sec: 109.641
# INFO:tensorflow:step = 14901, loss = 0.000589192 (0.916 sec)
# INFO:tensorflow:global_step/sec: 194.24
# INFO:tensorflow:step = 15001, loss = 0.000575748 (0.511 sec)
# INFO:tensorflow:global_step/sec: 169.494
# INFO:tensorflow:step = 15101, loss = 0.00232498 (0.592 sec)
# INFO:tensorflow:global_step/sec: 137.211
# INFO:tensorflow:step = 15201, loss = 0.00127851 (0.727 sec)
# INFO:tensorflow:global_step/sec: 200.42
# INFO:tensorflow:step = 15301, loss = 0.000888491 (0.500 sec)
# INFO:tensorflow:global_step/sec: 185.097
# INFO:tensorflow:step = 15401, loss = 0.000638248 (0.540 sec)
# INFO:tensorflow:global_step/sec: 175.205
# INFO:tensorflow:step = 15501, loss = 0.0035932 (0.570 sec)
# INFO:tensorflow:global_step/sec: 138.413
# INFO:tensorflow:step = 15601, loss = 0.000578437 (0.726 sec)
# INFO:tensorflow:global_step/sec: 183.388
# INFO:tensorflow:step = 15701, loss = 0.00227658 (0.542 sec)
# INFO:tensorflow:global_step/sec: 218.925
# INFO:tensorflow:step = 15801, loss = 0.00193673 (0.455 sec)
# INFO:tensorflow:global_step/sec: 212.957
# INFO:tensorflow:step = 15901, loss = 0.000253293 (0.470 sec)
# INFO:tensorflow:global_step/sec: 202.293
# INFO:tensorflow:step = 16001, loss = 0.000604486 (0.494 sec)
# INFO:tensorflow:global_step/sec: 203.966
# INFO:tensorflow:step = 16101, loss = 0.00124276 (0.490 sec)
# INFO:tensorflow:global_step/sec: 181.103
# INFO:tensorflow:step = 16201, loss = 0.0018008 (0.553 sec)
# INFO:tensorflow:global_step/sec: 164.08
# INFO:tensorflow:step = 16301, loss = 0.00117289 (0.609 sec)
# INFO:tensorflow:global_step/sec: 170.104
# INFO:tensorflow:step = 16401, loss = 0.000607091 (0.588 sec)
# INFO:tensorflow:global_step/sec: 190.007
# INFO:tensorflow:step = 16501, loss = 0.00184054 (0.527 sec)
# INFO:tensorflow:global_step/sec: 186.57
# INFO:tensorflow:step = 16601, loss = 9.01912e-05 (0.536 sec)
# INFO:tensorflow:global_step/sec: 153.719
# INFO:tensorflow:step = 16701, loss = 0.000433244 (0.652 sec)
# INFO:tensorflow:global_step/sec: 188.332
# INFO:tensorflow:step = 16801, loss = 0.000675305 (0.529 sec)
# INFO:tensorflow:global_step/sec: 188.615
# INFO:tensorflow:step = 16901, loss = 0.000651229 (0.530 sec)
# INFO:tensorflow:global_step/sec: 186.511
# INFO:tensorflow:step = 17001, loss = 0.000997982 (0.536 sec)
# INFO:tensorflow:global_step/sec: 203.828
# INFO:tensorflow:step = 17101, loss = 0.000812328 (0.490 sec)
# INFO:tensorflow:global_step/sec: 185.584
# INFO:tensorflow:step = 17201, loss = 0.00127112 (0.539 sec)
# INFO:tensorflow:global_step/sec: 168.636
# INFO:tensorflow:step = 17301, loss = 0.00159413 (0.594 sec)
# INFO:tensorflow:global_step/sec: 175.895
# INFO:tensorflow:step = 17401, loss = 9.89386e-05 (0.568 sec)
# INFO:tensorflow:global_step/sec: 174.371
# INFO:tensorflow:step = 17501, loss = 0.000823483 (0.574 sec)
# INFO:tensorflow:global_step/sec: 143.503
# INFO:tensorflow:step = 17601, loss = 0.000266055 (0.698 sec)
# INFO:tensorflow:global_step/sec: 184.975
# INFO:tensorflow:step = 17701, loss = 0.000287113 (0.540 sec)
# INFO:tensorflow:global_step/sec: 182.839
# INFO:tensorflow:step = 17801, loss = 0.00109404 (0.547 sec)
# INFO:tensorflow:global_step/sec: 182.187
# INFO:tensorflow:step = 17901, loss = 0.00030381 (0.549 sec)
# INFO:tensorflow:global_step/sec: 201.052
# INFO:tensorflow:step = 18001, loss = 0.000296798 (0.497 sec)
# INFO:tensorflow:global_step/sec: 204.514
# INFO:tensorflow:step = 18101, loss = 0.000225994 (0.489 sec)
# INFO:tensorflow:global_step/sec: 196.47
# INFO:tensorflow:step = 18201, loss = 0.000229392 (0.509 sec)
# INFO:tensorflow:global_step/sec: 102.891
# INFO:tensorflow:step = 18301, loss = 0.000362437 (0.973 sec)
# INFO:tensorflow:global_step/sec: 107.633
# INFO:tensorflow:step = 18401, loss = 0.000840753 (0.927 sec)
# INFO:tensorflow:global_step/sec: 173.035
# INFO:tensorflow:step = 18501, loss = 9.71515e-05 (0.580 sec)
# INFO:tensorflow:global_step/sec: 183.738
# INFO:tensorflow:step = 18601, loss = 0.000800913 (0.543 sec)
# INFO:tensorflow:global_step/sec: 204.347
# INFO:tensorflow:step = 18701, loss = 0.000743799 (0.489 sec)
# INFO:tensorflow:global_step/sec: 202.526
# INFO:tensorflow:step = 18801, loss = 0.000229441 (0.494 sec)
# INFO:tensorflow:global_step/sec: 180.587
# INFO:tensorflow:step = 18901, loss = 0.000211273 (0.554 sec)
# INFO:tensorflow:global_step/sec: 218.816
# INFO:tensorflow:step = 19001, loss = 0.000796679 (0.457 sec)
# INFO:tensorflow:global_step/sec: 206.315
# INFO:tensorflow:step = 19101, loss = 0.000425156 (0.485 sec)
# INFO:tensorflow:global_step/sec: 210.162
# INFO:tensorflow:step = 19201, loss = 0.000801675 (0.474 sec)
# INFO:tensorflow:global_step/sec: 160.671
# INFO:tensorflow:step = 19301, loss = 0.00139562 (0.623 sec)
# INFO:tensorflow:global_step/sec: 150.144
# INFO:tensorflow:step = 19401, loss = 0.000661248 (0.666 sec)
# INFO:tensorflow:global_step/sec: 150.187
# INFO:tensorflow:step = 19501, loss = 0.000325223 (0.666 sec)
# INFO:tensorflow:global_step/sec: 157.492
# INFO:tensorflow:step = 19601, loss = 0.000410199 (0.636 sec)
# INFO:tensorflow:global_step/sec: 176.115
# INFO:tensorflow:step = 19701, loss = 0.000145001 (0.566 sec)
# INFO:tensorflow:global_step/sec: 194.612
# INFO:tensorflow:step = 19801, loss = 0.000745825 (0.514 sec)
# INFO:tensorflow:global_step/sec: 107.114
# INFO:tensorflow:step = 19901, loss = 0.000123035 (0.937 sec)
# INFO:tensorflow:global_step/sec: 80.6529
# INFO:tensorflow:step = 20001, loss = 0.000657024 (1.237 sec)
# INFO:tensorflow:global_step/sec: 117.211
# INFO:tensorflow:step = 20101, loss = 0.000347711 (0.855 sec)
# INFO:tensorflow:global_step/sec: 147.401
# INFO:tensorflow:step = 20201, loss = 0.000283923 (0.676 sec)
# INFO:tensorflow:global_step/sec: 172.885
# INFO:tensorflow:step = 20301, loss = 0.000517246 (0.580 sec)
# INFO:tensorflow:global_step/sec: 174.78
# INFO:tensorflow:step = 20401, loss = 0.000316603 (0.582 sec)
# INFO:tensorflow:global_step/sec: 110.912
# INFO:tensorflow:step = 20501, loss = 0.000486804 (0.892 sec)
# INFO:tensorflow:global_step/sec: 119.186
# INFO:tensorflow:step = 20601, loss = 0.000479017 (0.841 sec)
# INFO:tensorflow:global_step/sec: 140.1
# INFO:tensorflow:step = 20701, loss = 0.000552744 (0.710 sec)
# INFO:tensorflow:global_step/sec: 134.929
# INFO:tensorflow:step = 20801, loss = 0.00201752 (0.742 sec)
# INFO:tensorflow:global_step/sec: 148.84
# INFO:tensorflow:step = 20901, loss = 0.000627046 (0.671 sec)
# INFO:tensorflow:global_step/sec: 211.882
# INFO:tensorflow:step = 21001, loss = 6.19904e-05 (0.472 sec)
# INFO:tensorflow:global_step/sec: 168.679
# INFO:tensorflow:step = 21101, loss = 0.00118224 (0.594 sec)
# INFO:tensorflow:global_step/sec: 117.646
# INFO:tensorflow:step = 21201, loss = 0.000564475 (0.850 sec)
# INFO:tensorflow:global_step/sec: 87.7854
# INFO:tensorflow:step = 21301, loss = 0.00053142 (1.139 sec)
# INFO:tensorflow:global_step/sec: 155.575
# INFO:tensorflow:step = 21401, loss = 0.000652821 (0.642 sec)
# INFO:tensorflow:global_step/sec: 201.501
# INFO:tensorflow:step = 21501, loss = 0.000642005 (0.496 sec)
# INFO:tensorflow:global_step/sec: 182.959
# INFO:tensorflow:step = 21601, loss = 0.000550134 (0.547 sec)
# INFO:tensorflow:global_step/sec: 186.598
# INFO:tensorflow:step = 21701, loss = 0.000264696 (0.535 sec)
# INFO:tensorflow:global_step/sec: 204.07
# INFO:tensorflow:step = 21801, loss = 0.00196883 (0.490 sec)
# INFO:tensorflow:global_step/sec: 202.603
# INFO:tensorflow:step = 21901, loss = 0.000287016 (0.493 sec)
# INFO:tensorflow:global_step/sec: 198.235
# INFO:tensorflow:step = 22001, loss = 7.46028e-05 (0.506 sec)
# INFO:tensorflow:global_step/sec: 184.161
# INFO:tensorflow:step = 22101, loss = 0.00197705 (0.543 sec)
# INFO:tensorflow:global_step/sec: 157.741
# INFO:tensorflow:step = 22201, loss = 0.000163154 (0.633 sec)
# INFO:tensorflow:global_step/sec: 163.941
# INFO:tensorflow:step = 22301, loss = 0.000156507 (0.610 sec)
# INFO:tensorflow:global_step/sec: 185.158
# INFO:tensorflow:step = 22401, loss = 0.000147735 (0.541 sec)
# INFO:tensorflow:global_step/sec: 182.702
# INFO:tensorflow:step = 22501, loss = 0.000355083 (0.547 sec)
# INFO:tensorflow:global_step/sec: 195.575
# INFO:tensorflow:step = 22601, loss = 0.000336649 (0.511 sec)
# INFO:tensorflow:global_step/sec: 186.46
# INFO:tensorflow:step = 22701, loss = 0.000275124 (0.537 sec)
# INFO:tensorflow:global_step/sec: 193.798
# INFO:tensorflow:step = 22801, loss = 0.000259674 (0.517 sec)
# INFO:tensorflow:global_step/sec: 159.638
# INFO:tensorflow:step = 22901, loss = 0.000371404 (0.625 sec)
# INFO:tensorflow:global_step/sec: 187.03
# INFO:tensorflow:step = 23001, loss = 0.000406521 (0.534 sec)
# INFO:tensorflow:global_step/sec: 190.242
# INFO:tensorflow:step = 23101, loss = 0.000330579 (0.527 sec)
# INFO:tensorflow:global_step/sec: 176.044
# INFO:tensorflow:step = 23201, loss = 0.000471875 (0.568 sec)
# INFO:tensorflow:global_step/sec: 182.452
# INFO:tensorflow:step = 23301, loss = 0.00090639 (0.547 sec)
# INFO:tensorflow:global_step/sec: 179.179
# INFO:tensorflow:step = 23401, loss = 0.000191514 (0.558 sec)
# INFO:tensorflow:global_step/sec: 174.783
# INFO:tensorflow:step = 23501, loss = 0.000565565 (0.573 sec)
# INFO:tensorflow:global_step/sec: 173.678
# INFO:tensorflow:step = 23601, loss = 0.000523166 (0.578 sec)
# INFO:tensorflow:global_step/sec: 173.882
# INFO:tensorflow:step = 23701, loss = 0.000387933 (0.572 sec)
# INFO:tensorflow:global_step/sec: 188.516
# INFO:tensorflow:step = 23801, loss = 0.0004756 (0.531 sec)
# INFO:tensorflow:global_step/sec: 191.705
# INFO:tensorflow:step = 23901, loss = 0.000693971 (0.522 sec)
# INFO:tensorflow:global_step/sec: 196.824
# INFO:tensorflow:step = 24001, loss = 0.000151052 (0.508 sec)
# INFO:tensorflow:global_step/sec: 191.219
# INFO:tensorflow:step = 24101, loss = 0.000959494 (0.523 sec)
# INFO:tensorflow:global_step/sec: 173.305
# INFO:tensorflow:step = 24201, loss = 0.000124877 (0.577 sec)
# INFO:tensorflow:global_step/sec: 178.116
# INFO:tensorflow:step = 24301, loss = 0.000640947 (0.563 sec)
# INFO:tensorflow:global_step/sec: 180.456
# INFO:tensorflow:step = 24401, loss = 0.000945868 (0.553 sec)
# INFO:tensorflow:global_step/sec: 186.438
# INFO:tensorflow:step = 24501, loss = 0.000443364 (0.537 sec)
# INFO:tensorflow:global_step/sec: 183.255
# INFO:tensorflow:step = 24601, loss = 0.000762276 (0.545 sec)
# INFO:tensorflow:global_step/sec: 199.09
# INFO:tensorflow:step = 24701, loss = 0.000244213 (0.502 sec)
# INFO:tensorflow:global_step/sec: 174.901
# INFO:tensorflow:step = 24801, loss = 0.000333532 (0.572 sec)
# INFO:tensorflow:global_step/sec: 194.911
# INFO:tensorflow:step = 24901, loss = 0.000500445 (0.513 sec)
# INFO:tensorflow:global_step/sec: 190.184
# INFO:tensorflow:step = 25001, loss = 0.000225041 (0.525 sec)
# INFO:tensorflow:global_step/sec: 197.336
# INFO:tensorflow:step = 25101, loss = 0.000331161 (0.507 sec)
# INFO:tensorflow:global_step/sec: 204.914
# INFO:tensorflow:step = 25201, loss = 0.000321896 (0.488 sec)
# INFO:tensorflow:global_step/sec: 187.879
# INFO:tensorflow:step = 25301, loss = 0.000328413 (0.532 sec)
# INFO:tensorflow:global_step/sec: 190.439
# INFO:tensorflow:step = 25401, loss = 8.64067e-05 (0.525 sec)
# INFO:tensorflow:global_step/sec: 205.581
# INFO:tensorflow:step = 25501, loss = 0.000899321 (0.486 sec)
# INFO:tensorflow:global_step/sec: 176.97
# INFO:tensorflow:step = 25601, loss = 0.00064676 (0.564 sec)
# INFO:tensorflow:global_step/sec: 193.976
# INFO:tensorflow:step = 25701, loss = 0.000210156 (0.516 sec)
# INFO:tensorflow:global_step/sec: 191.149
# INFO:tensorflow:step = 25801, loss = 0.000597821 (0.523 sec)
# INFO:tensorflow:global_step/sec: 207.451
# INFO:tensorflow:step = 25901, loss = 0.000145619 (0.482 sec)
# INFO:tensorflow:global_step/sec: 196.805
# INFO:tensorflow:step = 26001, loss = 0.000184369 (0.508 sec)
# INFO:tensorflow:global_step/sec: 194.289
# INFO:tensorflow:step = 26101, loss = 0.000234902 (0.515 sec)
# INFO:tensorflow:global_step/sec: 212.412
# INFO:tensorflow:step = 26201, loss = 0.000875326 (0.471 sec)
# INFO:tensorflow:global_step/sec: 196.901
# INFO:tensorflow:step = 26301, loss = 6.59155e-05 (0.508 sec)
# INFO:tensorflow:global_step/sec: 211.299
# INFO:tensorflow:step = 26401, loss = 0.000418321 (0.473 sec)
# INFO:tensorflow:global_step/sec: 205.46
# INFO:tensorflow:step = 26501, loss = 0.000771225 (0.487 sec)
# INFO:tensorflow:global_step/sec: 149.347
# INFO:tensorflow:step = 26601, loss = 0.000399551 (0.670 sec)
# INFO:tensorflow:global_step/sec: 172.307
# INFO:tensorflow:step = 26701, loss = 4.44197e-05 (0.580 sec)
# INFO:tensorflow:global_step/sec: 174.711
# INFO:tensorflow:step = 26801, loss = 0.000306825 (0.572 sec)
# INFO:tensorflow:global_step/sec: 175.296
# INFO:tensorflow:step = 26901, loss = 0.000662459 (0.571 sec)
# INFO:tensorflow:global_step/sec: 194.195
# INFO:tensorflow:step = 27001, loss = 0.00113821 (0.515 sec)
# INFO:tensorflow:global_step/sec: 194.679
# INFO:tensorflow:step = 27101, loss = 0.000694257 (0.514 sec)
# INFO:tensorflow:global_step/sec: 178.956
# INFO:tensorflow:step = 27201, loss = 0.000667649 (0.559 sec)
# INFO:tensorflow:global_step/sec: 197.606
# INFO:tensorflow:step = 27301, loss = 0.000156476 (0.506 sec)
# INFO:tensorflow:global_step/sec: 196.854
# INFO:tensorflow:step = 27401, loss = 0.000248564 (0.508 sec)
# INFO:tensorflow:global_step/sec: 185.252
# INFO:tensorflow:step = 27501, loss = 0.000111848 (0.540 sec)
# INFO:tensorflow:global_step/sec: 187.617
# INFO:tensorflow:step = 27601, loss = 0.000149715 (0.533 sec)
# INFO:tensorflow:global_step/sec: 186.022
# INFO:tensorflow:step = 27701, loss = 9.61971e-05 (0.537 sec)
# INFO:tensorflow:global_step/sec: 212.264
# INFO:tensorflow:step = 27801, loss = 0.000137038 (0.472 sec)
# INFO:tensorflow:global_step/sec: 206.248
# INFO:tensorflow:step = 27901, loss = 0.000504035 (0.484 sec)
# INFO:tensorflow:global_step/sec: 190.627
# INFO:tensorflow:step = 28001, loss = 0.000281306 (0.525 sec)
# INFO:tensorflow:global_step/sec: 200.558
# INFO:tensorflow:step = 28101, loss = 0.000768896 (0.498 sec)
# INFO:tensorflow:global_step/sec: 202.57
# INFO:tensorflow:step = 28201, loss = 0.000661956 (0.497 sec)
# INFO:tensorflow:global_step/sec: 169.853
# INFO:tensorflow:step = 28301, loss = 0.000319672 (0.586 sec)
# INFO:tensorflow:global_step/sec: 197.786
# INFO:tensorflow:step = 28401, loss = 0.000645049 (0.506 sec)
# INFO:tensorflow:global_step/sec: 178.72
# INFO:tensorflow:step = 28501, loss = 0.000410314 (0.560 sec)
# INFO:tensorflow:global_step/sec: 183.864
# INFO:tensorflow:step = 28601, loss = 0.000346522 (0.545 sec)
# INFO:tensorflow:global_step/sec: 194.614
# INFO:tensorflow:step = 28701, loss = 9.24276e-05 (0.514 sec)
# INFO:tensorflow:global_step/sec: 187.039
# INFO:tensorflow:step = 28801, loss = 0.000935963 (0.533 sec)
# INFO:tensorflow:global_step/sec: 167.446
# INFO:tensorflow:step = 28901, loss = 0.000390919 (0.598 sec)
# INFO:tensorflow:global_step/sec: 177.95
# INFO:tensorflow:step = 29001, loss = 0.00036199 (0.561 sec)
# INFO:tensorflow:global_step/sec: 175.024
# INFO:tensorflow:step = 29101, loss = 0.000582248 (0.571 sec)
# INFO:tensorflow:global_step/sec: 186.518
# INFO:tensorflow:step = 29201, loss = 0.00136019 (0.536 sec)
# INFO:tensorflow:global_step/sec: 198.798
# INFO:tensorflow:step = 29301, loss = 0.000360182 (0.503 sec)
# INFO:tensorflow:global_step/sec: 196.05
# INFO:tensorflow:step = 29401, loss = 0.0004857 (0.510 sec)
# INFO:tensorflow:global_step/sec: 173.704
# INFO:tensorflow:step = 29501, loss = 0.000130546 (0.576 sec)
# INFO:tensorflow:global_step/sec: 191.401
# INFO:tensorflow:step = 29601, loss = 6.18118e-05 (0.522 sec)
# INFO:tensorflow:global_step/sec: 178.912
# INFO:tensorflow:step = 29701, loss = 0.000529869 (0.559 sec)
# INFO:tensorflow:global_step/sec: 199.446
# INFO:tensorflow:step = 29801, loss = 0.000130589 (0.503 sec)
# INFO:tensorflow:global_step/sec: 198.051
# INFO:tensorflow:step = 29901, loss = 0.000175813 (0.503 sec)
# INFO:tensorflow:global_step/sec: 206.316
# INFO:tensorflow:step = 30001, loss = 0.000210899 (0.485 sec)
# INFO:tensorflow:global_step/sec: 198.928
# INFO:tensorflow:step = 30101, loss = 0.000633243 (0.504 sec)
# INFO:tensorflow:global_step/sec: 204.766
# INFO:tensorflow:step = 30201, loss = 0.000580604 (0.487 sec)
# INFO:tensorflow:global_step/sec: 191.826
# INFO:tensorflow:step = 30301, loss = 9.98706e-05 (0.523 sec)
# INFO:tensorflow:global_step/sec: 179.458
# INFO:tensorflow:step = 30401, loss = 0.000121904 (0.556 sec)
# INFO:tensorflow:global_step/sec: 193.161
# INFO:tensorflow:step = 30501, loss = 0.000146288 (0.518 sec)
# INFO:tensorflow:global_step/sec: 203.949
# INFO:tensorflow:step = 30601, loss = 0.00020745 (0.490 sec)
# INFO:tensorflow:global_step/sec: 193.481
# INFO:tensorflow:step = 30701, loss = 2.61336e-05 (0.518 sec)
# INFO:tensorflow:global_step/sec: 200.628
# INFO:tensorflow:step = 30801, loss = 8.3596e-05 (0.498 sec)
# INFO:tensorflow:global_step/sec: 210.651
# INFO:tensorflow:step = 30901, loss = 0.00021008 (0.475 sec)
# INFO:tensorflow:global_step/sec: 215.16
# INFO:tensorflow:step = 31001, loss = 0.000467658 (0.465 sec)
# INFO:tensorflow:global_step/sec: 207.7
# INFO:tensorflow:step = 31101, loss = 0.000338878 (0.481 sec)
# INFO:tensorflow:global_step/sec: 204.672
# INFO:tensorflow:step = 31201, loss = 0.000275955 (0.488 sec)
# INFO:tensorflow:global_step/sec: 193.015
# INFO:tensorflow:step = 31301, loss = 0.000636997 (0.518 sec)
# INFO:tensorflow:global_step/sec: 181.202
# INFO:tensorflow:step = 31401, loss = 0.000416144 (0.553 sec)
# INFO:tensorflow:global_step/sec: 208.692
# INFO:tensorflow:step = 31501, loss = 0.000137728 (0.477 sec)
# INFO:tensorflow:global_step/sec: 206.331
# INFO:tensorflow:step = 31601, loss = 0.000325332 (0.485 sec)
# INFO:tensorflow:global_step/sec: 171.273
# INFO:tensorflow:step = 31701, loss = 3.05867e-05 (0.584 sec)
# INFO:tensorflow:global_step/sec: 204.049
# INFO:tensorflow:step = 31801, loss = 0.000492186 (0.490 sec)
# INFO:tensorflow:global_step/sec: 193.153
# INFO:tensorflow:step = 31901, loss = 0.000628707 (0.519 sec)
# INFO:tensorflow:global_step/sec: 131.147
# INFO:tensorflow:step = 32001, loss = 0.000405203 (0.761 sec)
# INFO:tensorflow:global_step/sec: 181.178
# INFO:tensorflow:step = 32101, loss = 0.000717225 (0.552 sec)
# INFO:tensorflow:global_step/sec: 175.155
# INFO:tensorflow:step = 32201, loss = 0.000420565 (0.571 sec)
# INFO:tensorflow:global_step/sec: 208.245
# INFO:tensorflow:step = 32301, loss = 0.000290153 (0.480 sec)
# INFO:tensorflow:global_step/sec: 213.75
# INFO:tensorflow:step = 32401, loss = 0.000251954 (0.468 sec)
# INFO:tensorflow:global_step/sec: 204.481
# INFO:tensorflow:step = 32501, loss = 0.000324309 (0.489 sec)
# INFO:tensorflow:global_step/sec: 208.415
# INFO:tensorflow:step = 32601, loss = 0.000207778 (0.480 sec)
# INFO:tensorflow:global_step/sec: 209.226
# INFO:tensorflow:step = 32701, loss = 0.000137821 (0.478 sec)
# INFO:tensorflow:global_step/sec: 202.866
# INFO:tensorflow:step = 32801, loss = 0.000180132 (0.493 sec)
# INFO:tensorflow:global_step/sec: 207.937
# INFO:tensorflow:step = 32901, loss = 7.39777e-05 (0.481 sec)
# INFO:tensorflow:global_step/sec: 211.134
# INFO:tensorflow:step = 33001, loss = 0.000511573 (0.474 sec)
# INFO:tensorflow:global_step/sec: 197.008
# INFO:tensorflow:step = 33101, loss = 0.000433122 (0.508 sec)
# INFO:tensorflow:global_step/sec: 187.773
# INFO:tensorflow:step = 33201, loss = 0.000298782 (0.533 sec)
# INFO:tensorflow:global_step/sec: 191.229
# INFO:tensorflow:step = 33301, loss = 0.000346575 (0.523 sec)
# INFO:tensorflow:global_step/sec: 191.564
# INFO:tensorflow:step = 33401, loss = 0.000221682 (0.522 sec)
# INFO:tensorflow:global_step/sec: 194.935
# INFO:tensorflow:step = 33501, loss = 0.000417434 (0.513 sec)
# INFO:tensorflow:global_step/sec: 157.713
# INFO:tensorflow:step = 33601, loss = 0.000569574 (0.639 sec)
# INFO:tensorflow:global_step/sec: 94.1749
# INFO:tensorflow:step = 33701, loss = 0.000271002 (1.058 sec)
# INFO:tensorflow:global_step/sec: 141.896
# INFO:tensorflow:step = 33801, loss = 0.000132542 (0.706 sec)
# INFO:tensorflow:global_step/sec: 155.57
# INFO:tensorflow:step = 33901, loss = 0.000240908 (0.641 sec)
# INFO:tensorflow:global_step/sec: 165.779
# INFO:tensorflow:step = 34001, loss = 0.00069255 (0.604 sec)
# INFO:tensorflow:global_step/sec: 124.014
# INFO:tensorflow:step = 34101, loss = 0.000161378 (0.807 sec)
# INFO:tensorflow:global_step/sec: 114.279
# INFO:tensorflow:step = 34201, loss = 0.000257259 (0.875 sec)
# INFO:tensorflow:global_step/sec: 105.384
# INFO:tensorflow:step = 34301, loss = 3.63982e-05 (0.950 sec)
# INFO:tensorflow:global_step/sec: 133.962
# INFO:tensorflow:step = 34401, loss = 0.000327177 (0.745 sec)
# INFO:tensorflow:global_step/sec: 99.6741
# INFO:tensorflow:step = 34501, loss = 0.000491382 (1.007 sec)
# INFO:tensorflow:global_step/sec: 66.8645
# INFO:tensorflow:step = 34601, loss = 0.000373778 (1.493 sec)
# INFO:tensorflow:global_step/sec: 86.9437
# INFO:tensorflow:step = 34701, loss = 0.000123956 (1.148 sec)
# INFO:tensorflow:global_step/sec: 158.97
# INFO:tensorflow:step = 34801, loss = 0.000199544 (0.629 sec)
# INFO:tensorflow:global_step/sec: 187.63
# INFO:tensorflow:step = 34901, loss = 0.000227877 (0.533 sec)
# INFO:tensorflow:global_step/sec: 191.692
# INFO:tensorflow:step = 35001, loss = 0.00035211 (0.522 sec)
# INFO:tensorflow:global_step/sec: 191.177
# INFO:tensorflow:step = 35101, loss = 0.000186807 (0.523 sec)
# INFO:tensorflow:global_step/sec: 179.436
# INFO:tensorflow:step = 35201, loss = 0.000754184 (0.557 sec)
# INFO:tensorflow:global_step/sec: 197.184
# INFO:tensorflow:step = 35301, loss = 0.000228583 (0.507 sec)
# INFO:tensorflow:global_step/sec: 196.243
# INFO:tensorflow:step = 35401, loss = 0.000113635 (0.510 sec)
# INFO:tensorflow:global_step/sec: 184.608
# INFO:tensorflow:step = 35501, loss = 2.99453e-05 (0.542 sec)
# INFO:tensorflow:global_step/sec: 193.926
# INFO:tensorflow:step = 35601, loss = 0.000274996 (0.516 sec)
# INFO:tensorflow:global_step/sec: 202.218
# INFO:tensorflow:step = 35701, loss = 0.000239577 (0.495 sec)
# INFO:tensorflow:global_step/sec: 189.054
# INFO:tensorflow:step = 35801, loss = 0.000215477 (0.529 sec)
# INFO:tensorflow:global_step/sec: 173.283
# INFO:tensorflow:step = 35901, loss = 0.000371202 (0.577 sec)
# INFO:tensorflow:global_step/sec: 193.369
# INFO:tensorflow:step = 36001, loss = 0.000250338 (0.517 sec)
# INFO:tensorflow:global_step/sec: 188.977
# INFO:tensorflow:step = 36101, loss = 0.000192448 (0.529 sec)
# INFO:tensorflow:global_step/sec: 173.129
# INFO:tensorflow:step = 36201, loss = 0.000193228 (0.578 sec)
# INFO:tensorflow:global_step/sec: 190.202
# INFO:tensorflow:step = 36301, loss = 0.000160808 (0.526 sec)
# INFO:tensorflow:global_step/sec: 167.47
# INFO:tensorflow:step = 36401, loss = 5.63324e-05 (0.598 sec)
# INFO:tensorflow:global_step/sec: 157.587
# INFO:tensorflow:step = 36501, loss = 0.0001296 (0.635 sec)
# INFO:tensorflow:global_step/sec: 141.492
# INFO:tensorflow:step = 36601, loss = 0.000321576 (0.706 sec)
# INFO:tensorflow:global_step/sec: 101.052
# INFO:tensorflow:step = 36701, loss = 8.5857e-05 (0.991 sec)
# INFO:tensorflow:global_step/sec: 101.115
# INFO:tensorflow:step = 36801, loss = 0.000170326 (0.987 sec)
# INFO:tensorflow:global_step/sec: 69.8107
# INFO:tensorflow:step = 36901, loss = 8.55396e-05 (1.433 sec)
# INFO:tensorflow:global_step/sec: 139.656
# INFO:tensorflow:step = 37001, loss = 0.000123956 (0.716 sec)
# INFO:tensorflow:global_step/sec: 139.734
# INFO:tensorflow:step = 37101, loss = 0.000809739 (0.716 sec)
# INFO:tensorflow:global_step/sec: 165.139
# INFO:tensorflow:step = 37201, loss = 0.000199089 (0.605 sec)
# INFO:tensorflow:global_step/sec: 172.305
# INFO:tensorflow:step = 37301, loss = 0.000295719 (0.580 sec)
# INFO:tensorflow:global_step/sec: 194.231
# INFO:tensorflow:step = 37401, loss = 0.000527202 (0.515 sec)
# INFO:tensorflow:global_step/sec: 175.294
# INFO:tensorflow:step = 37501, loss = 0.000194788 (0.572 sec)
# INFO:tensorflow:global_step/sec: 193.443
# INFO:tensorflow:step = 37601, loss = 0.000542256 (0.517 sec)
# INFO:tensorflow:global_step/sec: 198.077
# INFO:tensorflow:step = 37701, loss = 8.5154e-05 (0.505 sec)
# INFO:tensorflow:global_step/sec: 204.142
# INFO:tensorflow:step = 37801, loss = 0.000452195 (0.490 sec)
# INFO:tensorflow:global_step/sec: 206.934
# INFO:tensorflow:step = 37901, loss = 0.000212734 (0.483 sec)
# INFO:tensorflow:global_step/sec: 193.211
# INFO:tensorflow:step = 38001, loss = 0.000704018 (0.516 sec)
# INFO:tensorflow:global_step/sec: 200.409
# INFO:tensorflow:step = 38101, loss = 0.000359998 (0.499 sec)
# INFO:tensorflow:global_step/sec: 195.301
# INFO:tensorflow:step = 38201, loss = 0.000440098 (0.512 sec)
# INFO:tensorflow:global_step/sec: 201.608
# INFO:tensorflow:step = 38301, loss = 0.000202331 (0.496 sec)
# INFO:tensorflow:global_step/sec: 197.429
# INFO:tensorflow:step = 38401, loss = 0.000487391 (0.507 sec)
# INFO:tensorflow:global_step/sec: 187.496
# INFO:tensorflow:step = 38501, loss = 0.000657095 (0.533 sec)
# INFO:tensorflow:global_step/sec: 185.073
# INFO:tensorflow:step = 38601, loss = 6.53735e-05 (0.540 sec)
# INFO:tensorflow:global_step/sec: 145.447
# INFO:tensorflow:step = 38701, loss = 3.48017e-05 (0.688 sec)
# INFO:tensorflow:global_step/sec: 188.405
# INFO:tensorflow:step = 38801, loss = 0.000157008 (0.531 sec)
# INFO:tensorflow:global_step/sec: 190.699
# INFO:tensorflow:step = 38901, loss = 0.000264725 (0.524 sec)
# INFO:tensorflow:global_step/sec: 172.624
# INFO:tensorflow:step = 39001, loss = 0.00052865 (0.579 sec)
# INFO:tensorflow:global_step/sec: 184.62
# INFO:tensorflow:step = 39101, loss = 7.36749e-05 (0.542 sec)
# INFO:tensorflow:global_step/sec: 190.263
# INFO:tensorflow:step = 39201, loss = 0.0004607 (0.526 sec)
# INFO:tensorflow:global_step/sec: 198.87
# INFO:tensorflow:step = 39301, loss = 5.76469e-05 (0.503 sec)
# INFO:tensorflow:global_step/sec: 187.778
# INFO:tensorflow:step = 39401, loss = 0.000287256 (0.534 sec)
# INFO:tensorflow:global_step/sec: 174.473
# INFO:tensorflow:step = 39501, loss = 0.00022557 (0.574 sec)
# INFO:tensorflow:global_step/sec: 173.285
# INFO:tensorflow:step = 39601, loss = 0.000202486 (0.576 sec)
# INFO:tensorflow:global_step/sec: 165.524
# INFO:tensorflow:step = 39701, loss = 2.21342e-05 (0.604 sec)
# INFO:tensorflow:global_step/sec: 179.946
# INFO:tensorflow:step = 39801, loss = 0.00011075 (0.556 sec)
# INFO:tensorflow:global_step/sec: 192.317
# INFO:tensorflow:step = 39901, loss = 4.70998e-05 (0.519 sec)
# INFO:tensorflow:Saving checkpoints for 40000 into /tmp/tmpncrcrp1x/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.000302292.
# DNNClassifier(params={'gradient_clip_norm': None, 'input_layer_min_slice_size': None, 'dropout': None, 'hidden_units': [300, 100], 'feature_columns': (_RealValuedColumn(column_name='', dimension=784, default_value=None, dtype=tf.float64, normalizer=None),), 'activation_fn': <function relu at 0x7f201e5d29d8>, 'head': <tensorflow.contrib.learn.python.learn.estimators.head._MultiClassHead object at 0x7f1fea8f11d0>, 'embedding_lr_multipliers': None, 'optimizer': None})

# %%
from sklearn.metrics import accuracy_score
predict_target = list(dnn_clf.predict_classes(test_data))
accuracy_score(test_target, predict_target)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/estimators/dnn.py:422: calling BaseEstimator.predict (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# INFO:tensorflow:Restoring parameters from /tmp/tmpncrcrp1x/model.ckpt-40000
# /opt/conda/lib/python3.5/site-packages/tensorflow/python/util/deprecation.py:248: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   equality = a == b
# 0.97714285714285709

# %%
from sklearn.metrics import accuracy_score
predict_target = list(dnn_clf.predict(test_data))
accuracy_score(test_target, predict_target)
# Out:
# WARNING:tensorflow:From /opt/conda/lib/python3.5/site-packages/tensorflow/python/util/deprecation.py:335: calling DNNClassifier.predict (from tensorflow.contrib.learn.python.learn.estimators.dnn) with outputs=None is deprecated and will be removed after 2017-03-01.
# Instructions for updating:
# Please switch to predict_classes, or set `outputs` argument.
# WARNING:tensorflow:From /opt/conda/lib/python3.5/site-packages/tensorflow/contrib/learn/python/learn/estimators/dnn.py:422: calling BaseEstimator.predict (from tensorflow.contrib.learn.python.learn.estimators.estimator) with x is deprecated and will be removed after 2016-12-01.
# Instructions for updating:
# Estimator is decoupled from Scikit Learn interface by moving into
# separate class SKCompat. Arguments x, y and batch_size are only
# available in the SKCompat class, Estimator will only accept input_fn.
# Example conversion:
#   est = Estimator(...) -> est = SKCompat(Estimator(...))
# WARNING:tensorflow:float64 is not supported by many models, consider casting to float32.
# /opt/conda/lib/python3.5/site-packages/tensorflow/python/util/deprecation.py:248: FutureWarning: comparison to `None` will result in an elementwise object comparison in the future.
#   equality = a == b
# INFO:tensorflow:Restoring parameters from /tmp/tmpncrcrp1x/model.ckpt-40000
# 0.97714285714285709

# %% [markdown]
# ### Hyperparameters
#
# __Number of hidden layers__
#
# > deep networks have a much higher parameter efficiency than shallow ones: they can model complex functions using exponentially fewer neurons than shallow nets, making them much faster to train
#
# > Real-world data is often ... hierarchical.
# - earlier hidden layers model low-level structures
# - intermediate hidden layers combine these low-level structures to model intermediate-level structures
# - later hidden layers (and the output layer) combine these intermediate structures to model high-level structures
#
# > In general you will get more bang for the buck by increasing the number of layers than the number of neurons per layer.
#
# __Number of neurons per layer__
#
# > a common practice is to size them ... with fewer and fewer neurons at each layer
#
# It is also common practice to make set the same number of neurons in each layer.
#
# __Activation functions__
#
# ReLU is a good/common choice.
#
# > For the output layer, the softmax activation function is generally a good choice for classification tasks (when the classes are mutually exclusive). For regression tasks, you can simply use no activation function at all.
